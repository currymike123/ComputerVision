# %% [markdown]
# Emmanuel Johnson<br>
# Professor Curry<br>
# CPS 493 Image Processing<br>
# 02/02/2023<br>
# Assignment 1<br>

# %%
#Question 1
#1D array
image = [50,75,100,125,150,175,200,225,250]
print(image)

#2D array
image = [[50,75,100],[125,150,175],[200,225,250]]
print(image)
# Out:
# [50, 75, 100, 125, 150, 175, 200, 225, 250]
# [[50, 75, 100], [125, 150, 175], [200, 225, 250]]

# %% [markdown]
# <b>(2) 50,75,100,125,150,175,200,225,250. In a 1D array, what is the array position of the value 150?</b><br>
#     The array position of 150 in the 1D array is position 4.
#
# <b>(3) 50,75,100,125,150,175,200,225,250. In a 2D array, what is the array position of the value 150?</b><br>
#     The array position of 150 in the 2D array is position row 1 position 1, or [1][1].

# %%
#Question 4
import cv2
import numpy as np
import matplotlib.pyplot as plt


imgFace = cv2.imread('derp.jpg',-1)

imgFace = cv2.cvtColor(imgFace, cv2.COLOR_BGR2RGB)
plt.imshow(imgFace)
