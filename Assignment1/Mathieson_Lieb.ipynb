# %% [markdown]
# # Assignment 1
# ## Computer Vision
# ### Lieb Mathieson
# #### Feb 2, 2023

# %%
#import libraries for every notebook going forward
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#saving an image

# img = cv2.imread()

# %%
#Create an image

firstImage = [[0,50,150,50,0],[50,175,200,175,50],[150,213,255,230,150],[50,175,200,175,50],[0,50,150,50,0]]
plt.imshow(firstImage, cmap='gray')

# %%
#3d array

#color w/0 alpha // alpha = -1
imgDoor = cv2.imread('Images/The_Door.jpg',1) # The_Door.jpg location may change

# convert bgr to rgb to see image correctly
imgDoor = cv2.cvtColor(imgDoor, cv2.COLOR_BGR2RGB)

print(imgDoor)
# Out:
# [[[127 127 127]
#   [127 127 127]
#   [127 127 127]
#   ...
#   [127 127 127]
#   [127 127 127]
#   [127 127 127]]
#
#  [[127 127 127]
#   [127 127 127]
#   [127 127 127]
#   ...
#   [127 127 127]
#   [127 127 127]
#   [127 127 127]]
#
#  [[127 127 127]
#   [127 127 127]
#   [127 127 127]
#   ...
#   [127 127 127]
#   [127 127 127]
#   [127 127 127]]
#
#  ...
#
#  [[127 127 127]
#   [127 127 127]
#   [127 127 127]
#   ...
#   [127 127 127]
#   [127 127 127]
#   [127 127 127]]
#
#  [[127 127 127]
#   [127 127 127]
#   [127 127 127]
#   ...
#   [127 127 127]
#   [127 127 127]
#   [127 127 127]]
#
#  [[127 127 127]
#   [127 127 127]
#   [127 127 127]
#   ...
#   [127 127 127]
#   [127 127 127]
#   [127 127 127]]]

# %% [markdown]
# # Assignment 1

# %% [markdown]
# **(1)** 50,75,100,125,150,175,200,225,250.  Show this sequence of values in a 1D and 2D array. <br><br>

# %%
oneD = [50,75,100,125,150,175,200,225,250]
twoD =[[50,75,100],[125,150,175],[200,225,250]]

print(oneD)
print(twoD)
plt.imshow(twoD, cmap='gray')
# Out:
# [50, 75, 100, 125, 150, 175, 200, 225, 250]
# [[50, 75, 100], [125, 150, 175], [200, 225, 250]]

# %% [markdown]
# **(2)** 50,75,100,125,150,175,200,225,250.  In a 1D array, what is the array position of the value 150?<br><br>

# %%
# 4
print(oneD[4])
# Out:
# 150

# %% [markdown]
# **(3)** 50,75,100,125,150,175,200,225,250.  In a 2D array, what is the array position of the value 150?<br><br>

# %%
# [1][1]
print(twoD[1][1])
# Out:
# 150

# %% [markdown]
# **(4)** Find a photo from Google Images, save it as a variable, and draw it using matplotlib.<br><br>

# %%
#3d array

imgDoor = cv2.imread('Images/The_Door.jpg',1) 

# convert bgr to rgb to see image correctly
imgDoor = cv2.cvtColor(imgDoor, cv2.COLOR_BGR2RGB)

plt.imshow(imgDoor)
