# %%
#creating list with given sequence
image= 50,75,100,125,150,175,200,225,250

# Convert the list to a 1D array
import numpy as np
arr1 = np.array(image)

# Printing 1D array
print(arr1)
arr2 = np.array(image).reshape(3,3)

# Printing 2D array
print(arr2)
# Out:
# [ 50  75 100 125 150 175 200 225 250]
# [[ 50  75 100]
#  [125 150 175]
#  [200 225 250]]

# %%
#creating list with given sequence
image= 50,75,100,125,150,175,200,225,250

value = 150
#print position
print("position of value",value)
image.index(150, 0, 8)
# Out:
# position of value 150
# 4

# %%
#creating list with given sequence
image= 50,75,100,125,150,175,200,225,250
# Create a list with the seqence of values
arr2 = np.array(image).reshape(3,3)
#print 2D-array
print(arr2)

value = 150
#get position in 2D-array
for i in range(3):
  for j in range(3):
    if value == arr2[i][j]:
        position = (i, j)
        break
#print position
print("position of value", value, "in the 2D array is", position)
l= 50,75,100,125,150,175,200,225,250
# Out:
# [[ 50  75 100]
#  [125 150 175]
#  [200 225 250]]
# position of value 150 in the 2D array is (1, 1)

# %%
#Import Libraries

import matplotlib.pyplot as plt

#Saving an image. 0 for grayscale. 1 for color. -1 for color with a alpha channel. 
img=plt.imread("picture.jpeg",0)

#display image
plt.imshow(img)
# hiding X-axis and Y-axis of the image
plt.axis('on')
plt.show()
