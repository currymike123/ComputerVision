# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image  = [50,75,100,125,150,175,200,225,250]
image2d = [[50,75,100],[125,150,175],[200,225,250]]

def location(x, y, w):
    location = x+(y*w)
    print(location)

location(1,1,3) # location should be 4

#position in a 2d array is column 1 row 1

img = cv2.imread("sharky.jpg", 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
# Out:
# 4
