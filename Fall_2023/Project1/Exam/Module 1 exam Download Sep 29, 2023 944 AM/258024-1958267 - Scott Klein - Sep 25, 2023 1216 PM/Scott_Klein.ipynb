# %%
#code from module 2 used

import cv2
import numpy as np
import matplotlib.pyplot as plt

#import image
img = cv2.imread('input.png', 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


#save black color
black = np.array([0,0,0])

h = img.shape[0]
w = img.shape[1]
for y in range(0,h):
    for x in range(0,w):
        if(img[y,x,2] > 150):
            img[y,x,0] = 0
            img[y,x,1] = 0
            img[y,x,2] = 0
        
     

              

plt.imshow(img)
