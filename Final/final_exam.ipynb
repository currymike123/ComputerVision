# %% [markdown]
# Question 1:
# <ol type="a">
#     <li>Explain the concept of a pixel and its role in digital images. Such as how are pixels used to represent color in RGB color systems?</li>
# </ol><p>.<hr><p>.<hr><p>.<hr><p>.<hr>
#
# Question 2:
# <ol type="a">
#     <li>Which of the following statements regarding color spaces is true?
#         <ol type="a">
#             <li>RGB and HSV are the only color spaces used in digital systems.</li>
#             <li>Color spaces have no impact on how color is perceived by humans.</li>
#             <li>HSV separates brightness, hue, and sensation for encoding color information.</li>
#             <li>Color spaces are primarily used for file compression purposes.</li>
#         </ol>
#     </li>
# </ol>
#
# Question 3:
# <ol type="a">
#     <li>Which of the following file formats is commonly used for high-quality practical compression of raster images?
#         <ol type="a">
#             <li>AI</li>
#             <li>JPEG</li>
#             <li>PDF</li>
#             <li>SVG</li>
#         </ol>
#     </li>
# </ol>
#
# Question 4:
# <ol type="a">
#     <li>Which of the following is the purpose of a mask in image processing?
#         <ol type="a">
#             <li>To convert an image from BGR to RGB color space.</li>
#             <li>To analyze a specific region in an image.</li>
#             <li>To apply mathematical operations on an image.</li>
#             <li>To increase the contrast of an image.</li>
#         </ol>
#     </li>
# </ol>
#
# Question 5:
# <ol type="a">
#     <li>Which of the following statements about NumPy arrays is correct?
#         <ol type="a">
#             <li>NumPy arrays cannot be accessed using indices.</li>
#             <li>Only NumPy arrays can slice/filter out elements.</li>
#             <li>NumPy arrays do not support mathematical operations.</li>
#             <li>NumPy arrays can set data types and support mathematical operations.</li>
#         </ol>
#     </li>
# </ol>
#
# Question 6:
# <ol type="a">
#     <li>What is the purpose of converting the image to grayscale before applying the Threshold filter?
#         <ol type="a">
#             <li>To remove any color information and only focus on brightness values.</li>
#             <li>To identify the locations of black pixels in the image.</li>
#             <li>To calculate the total number of pixels in the image.</li>
#             <li>To improve the resolution and quality of the image.</li>
#         </ol>
#     </li>
# </ol>
#
# Question 7:
# <ol type="a">
#     <li>Which interpolation method uses a 4x4 frame and 16 nearest neighbors to find the new pixel value?
#         <ol type="a">
#             <li>Linear Interpolation</li>
#             <li>Bi-Linear Interpolation</li>
#             <li>BiCubic Interpolation</li>
#             <li>Nearest Neighbor Interpolation</li>
#         </ol>
#     </li>
# </ol>
#
# Question 8:
# <ol type="a">
#     <li>What happens if the sum of the kernel used for convolution does not equal one?
#         <ol type="a">
#             <li>The image becomes sharpened.</li>
#             <li>The image becomes blurred.</li>
#             <li>The image becomes lighter or darker.</li>
#             <li>The image remains unchanged.</li>
#         </ol>
#     </li>
# </ol>
#
# Question 9:
# <ol type="a">
#     <li>What is the purpose of applying an edge filter to an image?
#         <ol type="a">
#             <li>To de-emphasize the differences in adjacent pixels.</li>
#             <li>To emphasize the differences in adjacent pixels.</li>
#             <li>To change the RGB values of each pixel.</li>
#             <li>To sharpen the image.</li>
#         </ol>
#     </li>
# </ol>
#
# Question 10:
# <ol type="a">
#     <li>Which step in the Canny edge detection process involves applying a Gaussian filter to the input image?
#         <ol type="a">
#             <li>Double thresholding.</li>
#             <li>Finding intensity gradients.</li>
#             <li>Non-maximum suppression.</li>
#             <li>Smoothing/Noise Reduction</li>
#         </ol>
#     </li>
# </ol>
#
# Question 11:
# <ol type="a">
#     <li>What does the 4:2:2 color subsampling in image compression leverage about the human eye?
#         <ol type="a">
#             <li>The higher sensitivity of the human eye to color than to brightness.</li>
#             <li>The higher sensitivity of the human eye to brightness than to color.</li>
#             <li>The ability of the human eye to distinguish a wide range of color shades.</li>
#             <li>The ability of the human eye to adapt to changes in lighting conditions.</li>
#         </ol>
#     </li>
# </ol>
#
#
# Question 12:
#
# `contours, hierarchy = cv2.findContours(dst, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)`
# <ol type="a">
#     <li>The above line of code is used to find the contours in an image. What does the variable `hierarchy` represent?
#         <ol type="a">
#             <li>The number of contours in the image.</li>
#             <li>The number of pixels in each contour.</li>
#             <li>The relationship between contours.</li>
#             <li>The relationship between pixels in each contour.</li>
#         </ol>
#     </li>
# </ol>
#
# Question 13:
# <ol type="a">
#     <li>Which of the following statements accurately describes the Viola-Jones algorithm used for face detection?
#         <ol type="a">
#             <li>It uses a neural network to detect faces in real-time.</li>
#             <li>It searches for rectangular patterns that capture local structures and compares them with a neighboring region.</li>
#             <li>It uses color histograms to identify facial regions.</li>
#             <li>It relies on color-based thresholding to distinguish faces from the background.</li>
#         </ol>
#     </li>
# </ol>
#
# Question 14:
#
# <ol type="a">
#     <li>What is the main purpose of binary image analysis?
#         <ol type="a">
#             <li>Segmenting and extracting objects from an image.</li>
#             <li>Converting grayscale images to binary representation.</li>
#             <li>Enhancing image resolution and clarity.</li>
#             <li>Applying color-based filters to highlight specific regions.</li>
#         </ol>
#     </li>
# </ol>
#
# Question 15:
#
# Question:
# How can you use OpenCV to find the bounding boxes of objects in an image?  The objects are on a white background so the background will not be an issue.
#
# Please provide a step-by-step approach using OpenCV to find the bounding boxes of objects in an image.  Pseudo code only is fine.  You do not need to write any code.  You can use any OpenCV functions you like.  Please explain why you chose the functions you did.  Please explain why your approach will work.  Please explain any limitations of your approach.
