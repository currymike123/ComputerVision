# %% [markdown]
# ## Final Exam
# ****
#
# Name:
# ****
# <br><br>
#
# <b>Question 1</b> (5 points):
#
# Explain the concept of a pixel and its role in digital images. Such as how are pixels used to represent color?  or how they are stored?
#
# Answer:<br><br><br><br><br><br><br><br><br><br><br><br><br>
#
# <hr>
#
# <b>Question 2</b> (5 points):
# <ul>
#     <li>Which of the following statements regarding color spaces is true?<p></p>
#         <ol type="a">
#             <li>RGB and HSV are the only color spaces used in digital systems.</li>
#             <li>Color spaces have no impact on how color is perceived by humans.</li>
#             <li>HSV separates brightness, hue, and saturation for encoding color information.</li>
#             <li>Color spaces are primarily used for file compression purposes.</li>
#         </ol>
#     </li>
# </ul>
# Answer:<br>
#
# <hr>
# <div style="page-break-after: always;"></div>
# <b>Question 3</b> (5 points):
# <ul type="a">
#     <li>Which of the following file formats is commonly used for high-quality practical compression of raster images?<p></p>
#         <ol type="a">
#             <li>AI</li>
#             <li>JPEG</li>
#             <li>PDF</li>
#             <li>SVG</li>
#         </ol>
#     </li>
# </ul>
# Answer:<br>
#
# <hr>
#
# <b>Question 4</b> (5 points):
# <ul type="a">
#     <li>Which of the following is the purpose of a mask in image processing?<p></p>
#         <ol type="a">
#             <li>To convert an image from BGR to RGB color space.</li>
#             <li>To analyze or transform a specific region in an image.</li>
#             <li>To apply mathematical operations to the whole image.</li>
#             <li>To increase the contrast of an image.</li>
#         </ol>
#     </li>
# </ul>
# Answer:<br>
#
# <hr>
#
# <b>Question 5</b> (5 points):
# <ul type="a">
#     <li>Which of the following statements about NumPy arrays is correct?<p></p>
#         <ol type="a">
#             <li>NumPy arrays cannot be accessed using indices.</li>
#             <li>Only NumPy arrays can slice/filter out elements.</li>
#             <li>NumPy arrays do not support mathematical operations.</li>
#             <li>NumPy arrays can set data types and support mathematical operations.</li>
#         </ol>
#     </li>
# </ul>
#
# Answer:<br>
#
# <hr>
#
# <b>Question 6</b> (5 points):
# <ul type="a">
#     <li>What is the purpose of converting an image to grayscale before applying a Threshold filter?<p></p>
#         <ol type="a">
#             <li>To remove any color information and only focus on brightness values.</li>
#             <li>To identify the locations of black pixels in the image.</li>
#             <li>To calculate the total number of pixels in the image.</li>
#             <li>To improve the resolution and quality of the image.</li>
#         </ol>
#     </li>
# </ul>
# Answer:<br>
#
# <hr>
# <div style="page-break-after: always;"></div>
# <b>Question 7</b> (5 points):
# <ul type="a">
#     <li>Which interpolation method uses a 4x4 frame and 16 nearest neighbors to find the new pixel value?<p></p>
#         <ol type="a">
#             <li>Linear Interpolation</li>
#             <li>Bi-Linear Interpolation</li>
#             <li>BiCubic Interpolation</li>
#             <li>Nearest Neighbor Interpolation</li>
#         </ol>
#     </li>
# </ul>
# Answer:<br>
#
# <hr>
# <b>Question 8</b> (5 points):
# <ul type="a">
#     <li>What happens if the sum of the kernel used for convolution does not equal one?<p></p>
#         <ol type="a">
#             <li>The image becomes sharpened.</li>
#             <li>The image becomes blurred.</li>
#             <li>The image becomes lighter or darker.</li>
#             <li>The image remains unchanged.</li>
#         </ol>
#     </li>
# </ul>
# Answer:<br>
#
# <hr>
# <b>Question 9</b> (5 points):
# <ul type="a">
#     <li>What is the purpose of applying an edge filter to an image?<p></p>
#         <ol type="a">
#             <li>To de-emphasize the differences in adjacent pixels.</li>
#             <li>To emphasize the differences in adjacent pixels.</li>
#             <li>To change the RGB values of each pixel.</li>
#             <li>To sharpen the image.</li>
#         </ol>
#     </li>
# </ul>
#
# Answer:<br>
#
# <hr>
#
# <b>Question 10</b> (5 points):
# <ul type="a">
#     <li>Why do the Prewitt and Sobel filters use two kernels?<p></p>
#         <ol type="a">
#             <li>The two kernels enhance the overall image contrast by applying different intensity transformations.</li>
#             <li>The two kernels enable noise reduction and image smoothing for better visual clarity.</li>
#             <li>The two kernels ensure compatibility with different color spaces, such as RGB and grayscale.</li>
#             <li>The two kernels allow for more accurate edge detection in both vertical and horizontal directions.</li>
#         </ol>
#     </li>
# </ul>
# Answer:<br>
#
# <hr>
#
# <b>Question 11</b> (5 points):
# <ul type="a">
#     <li>Which step in the Canny edge detection process involves applying a Blur/Gaussian filter to the input image?<p></p>
#         <ol type="a">
#             <li>Double thresholding.</li>
#             <li>Finding intensity gradients.</li>
#             <li>Non-maximum suppression.</li>
#             <li>Smoothing/Noise Reduction</li>
#         </ol>
#     </li>
# </ul>
# Answer:<br>
#
# <hr>
# <b>Question 12</b> (5 points):
# <ul type="a">
#     <li>What does the 4:2:2 color subsampling in image compression leverage about the human eye?<p></p>
#         <ol type="a">
#             <li>The higher sensitivity of the human eye to color than to brightness.</li>
#             <li>The higher sensitivity of the human eye to brightness than to color.</li>
#             <li>The ability of the human eye to distinguish a wide range of color shades.</li>
#             <li>The ability of the human eye to adapt to changes in lighting conditions.</li>
#         </ol>
#     </li>
# </ul>
# Answer:<br>
#
# <hr>
#
# <b>Question 13</b> (5 points):
# <br><br>
# <code>contours, hierarchy = cv2.findContours(dst, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)</code>
# <ul>
#     The above line of code is used to find the contours in an image. What does `hierarchy` represent?<p></p>
#         <ol type="a">
#             <li>The number of contours in the image.</li>
#             <li>The number of pixels in each contour.</li>
#             <li>The relationship between contours.</li>
#             <li>The relationship between pixels in each contour.</li>
#         </ol>
#     </li>
# </ul>
# Answer:<br>
#
# <hr>
# <div style="page-break-after: always;"></div>
# <b>Question 14</b> (5 points):
# <ul type="a">
#     <li>What makes corners important features in image processing?<p></p>
#         <ol type="a">
#             <li>Corners have a consistent brightness value throughout the image..</li>
#             <li>Corners exhibit significant brightness variations in all directions.</li>
#             <li>Corners are primarily located in the center of the image.</li>
#             <li>Corners provide a measure of image sharpness and contrast.</li>
#         </ol>
#     </li>
# </ul>
# Answer:<br>
#
# <hr>
#
# <b>Question 15</b> (5 points):
# <ul type="a">
#     <li>Which of the following statements accurately describes the Viola-Jones algorithm used for face detection?<p></p>
#         <ol type="a">
#             <li>It uses a neural network to detect faces in real-time.</li>
#             <li>It searches for rectangular patterns that capture local structures and compares them with a neighboring region.</li>
#             <li>It uses color histograms to identify facial regions.</li>
#             <li>It relies on color-based thresholding to distinguish faces from the background.</li>
#         </ol>
#     </li>
# </ul>
# Answer:<br>
#
# <hr>
# <b>Question 16</b> (5 points):
#
# <ul type="a">
#     <li>What is the main purpose of binary image analysis?<p></p>
#         <ol type="a">
#             <li>Searching for corners to segment an image and extract objects.</li>
#             <li>Converting color images to a grayscale representation.</li>
#             <li>Enhancing image resolution and clarity.</li>
#             <li>Applying color-based filters to highlight specific regions.</li>
#         </ol>
#     </li>
# </ul>
#
# Answer:<br>
#
# <hr>
# <div style="page-break-after: always;"></div>
# <b>Question 17</b> (10 points):
#
# Using convolution apply this kernel to the following image.  What is the resulting pixel value?  Center the kernel on the middle pixel(30).
# $$
# \text{Image}
# \begin{bmatrix}
# 50 & 40 & 30 \\
# 40 & 30 & 20 \\
# 30 & 20 & 10 \\
# \end{bmatrix}
# \text{X}
# \begin{bmatrix}
# 0 & -1 & 0\\
# -1 & 5 & 0\\
# 0 & -1 & 0
# \end{bmatrix}
# \text{Kernel}
# $$
# Answer:<br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <hr>
# <b>Question 18</b> (10 points):
# Question:
# How can you use OpenCV to find the bounding boxes of objects in an image?  The objects in the image are on a white background so the background will not be an issue.
#
# Please provide a step-by-step approach using OpenCV to find the bounding boxes of objects in an image.  Pseudo code only.  You do not need to write any OpenCV code.  Just describe a step-by-step process.  Please explain why your approach will work.  Please explain any limitations of your approach.
#
# Answer:<br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <hr>
