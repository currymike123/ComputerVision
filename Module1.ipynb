# %% [markdown]
# # Module 1: Images and Pixels
#
# "Only light generates color. Without light, no color exists" - Linda Holtzschue
# ****

# %% [markdown]
# All digital images are made up of a grid (2D Array) of pixels.  Each location in the grid is given three values.  The combonation of these values reprents the pixel color.
#
# Color can be interpreted in many different ways.  The two main color systems we will discuss are:
#
# **RGB:** Red, Green, Blue
#
# **HSB:** Hue, Saturation, Brightness

# %%
#Install Open CV
# %pip install opencv-contrib-python
