# %% [markdown]
# Name:
# ****
#
# ### (1) Which one of the following color systems is subtractive? (10 pts)
# <ol type="A">
#   <li>HSV</li>
#   <li>CMYK</li>
#   <li>RGB</li>
#   <li>None of the above</li>
# </ol>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;Answer: __________
# <p>
#
# ### (2) OpenCv stores RGB color images in an array with how many dimensions? (10 pts)
# <ol type="A">
#   <li>Three dimensional</li>
#   <li>One dimensional</li>
#   <li>Two dimensional</li>
#   <li>None of the above</li>
# </ol>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;Answer: __________
# <p>
#
# ### (3) Image data is imported by OpenCv in what data type? (10 pts)
# <ol type="A">
#   <li>Signed 16 bit integer</li>
#   <li>64 bit floating point number</li>
#   <li>Unsigned 8 bit integer</li>
#   <li>None of the above</li>
# </ol>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;Answer: __________
# <p>
#
# ### (4) The following pixel grid is stored in a 3D array, what is the array position of the number 60? (10 pts)
# <table>
#   <tr>
#     <td>55,100,200</td>
#     <td>74,124,100</td>
#     <td>89,210,10</td>
#   </tr>
#   <tr>
#     <td>124,74,191</td>
#     <td>174,43,34 </td>
#     <td>201,142,60 </td>
#   </tr>
#   <tr>
#     <td>191,50,10</td>
#     <td>215,111,84</td>
#     <td>245,139,81</td>
#   </tr>
# </table>
# <p>
# <ol type="A">
#   <li>[2][2][2]</li>
#   <li>[1][2][3]</li>
#   <li>[1][2][2]</li>
#   <li>[2][2][1]</li>
#   <li>None of the above</li>
# </ol>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;Answer: __________
# <p>
#
# ### (5) HSV encodes color information by separating out the brightness (value or intensity) value from? (10 pts)
#
# <ol type="A">
#   <li>The two values for encoding chromaticity (color).</li>
#   <li>The Red, Green, and Blue color channels.</li>
#   <li>The additive color system.</li>
#   <li>None of the above</li>
# </ol>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;Answer: __________
# <p>
#
#
# ### (6) A black and white image histogram is a plot of? (10 pts)
#
# <ol type="A">
#   <li>The angle of the Hue value.</li>
#   <li>The array position of the pixel values.</li>
#   <li>The brightness (intensity) distribution of the pixel data along it's value range.</li>
#   <li>The largest saturation value in the image.</li>
# </ol>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;Answer: __________
# <p>
#
# ### (7)) Which is not a Raster file type and does not store pixel data in an array? (10 pts)
#
# <ol type="A">
#   <li>TIFF</li>
#   <li>JPEG</li>
#   <li>PostScript (PDF)</li>
#   <li>PNG</li>
# </ol>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;Answer: __________
# <p>
#
# ### (8) <b>True or False:</b> A Python list does support mathematical operations, so the following code will output [2,4,6]. (10 pts)
# ```
# list = [1,2,3]
# list = list * 2
# print(list)
#
# ```
#
# &nbsp;&nbsp;&nbsp;&nbsp;Answer: __________
# <p>
#
# ### (9)  Write the Pseudo Code for the image pipeline we built in class for skin tracking. (20 pts)<p>
#  You can write the comments for each step or a plain english explanation.  Just be as clear as possible.<p>
#  Your first line should be: <b>Import image.</b><br>
#  Your last line should be: <b>Draw masked image.</b>
