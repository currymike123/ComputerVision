# %% [markdown]
# # Module 1a: Color Systems & File Types
#
# ****

# %% [markdown]
# ### Color Spaces & Theory

# %% [markdown]
# ### Three Axis Color
#
# **RGB & CMYK** can be visualized in a cube.<br><br>
# <img src="Graphics/threeaxis.png"><br>
#
# Other color spaces exist such as HSV (HSB) & YCrCb.<br>
#
# **HSV, HSB, HSI**<br><br>
# HSV stands for Hue, Saturation, and Value.  You may see it called HSB or HSI (brightness and intensity).  You can visualize the HSV color space in a cylinder or more precisely in a hexacone.  <br>
#
# HSV encodes color information by seperating out the brightness (value or intensity) value from the two values encoding chromaticity, Hue and Saturation. <br><br>
# The hue is defined by the angle between 0 and 2&pi; . &pi;(radians) being equal to 180&deg; and 2&pi; being equal to 360&deg;.  &pi; $\approx$ 3.14 | 2&pi; $\approx$ 6.28
# + Pure red is an angle of 0&deg;
# + Pure green is at 2&pi;/3 or 120&deg;
# + Pure blue is at 4&pi;/3 or 240&deg;
#
# <br><br>
# <img src="Graphics/hsv_hexacone.png"><br>
# <img src="Graphics/rgbvshsb.jpeg"><br>

# %% [markdown]
# **RGB -> HSV**
#
# In case of 8-bit and 16-bit images, R, G, and B are converted to the floating-point format and scaled to fit the 0 to 1 range.<br><br>
#
# <p class="formulaDsp">
# <span class="MathJax_Preview" style="display: none;"></span><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-20-Frame" tabindex="0" style="text-align: center;"><nobr><span class="math" id="MathJax-Span-355" style="width: 8.858em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.323em; height: 0px; font-size: 121%;"><span style="position: absolute; clip: rect(1.715em, 1007.26em, 2.896em, -999.997em); top: -2.535em; left: 0em;"><span class="mrow" id="MathJax-Span-356"><span class="mi" id="MathJax-Span-357" style="font-family: STIXGeneral-Italic;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-358" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">←</span><span class="mi" id="MathJax-Span-359" style="font-family: STIXGeneral-Italic; padding-left: 0.298em;">m</span><span class="mi" id="MathJax-Span-360" style="font-family: STIXGeneral-Italic;">a</span><span class="mi" id="MathJax-Span-361" style="font-family: STIXGeneral-Italic;">x<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-362" style="font-family: STIXGeneral-Regular;">(</span><span class="mi" id="MathJax-Span-363" style="font-family: STIXGeneral-Italic;">R</span><span class="mo" id="MathJax-Span-364" style="font-family: STIXGeneral-Regular;">,</span><span class="mi" id="MathJax-Span-365" style="font-family: STIXGeneral-Italic; padding-left: 0.18em;">G</span><span class="mo" id="MathJax-Span-366" style="font-family: STIXGeneral-Regular;">,</span><span class="mi" id="MathJax-Span-367" style="font-family: STIXGeneral-Italic; padding-left: 0.18em;">B</span><span class="mo" id="MathJax-Span-368" style="font-family: STIXGeneral-Regular;">)</span></span><span style="display: inline-block; width: 0px; height: 2.541em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 1.146em;"></span></span></nobr></span></div><script type="math/tex; mode=display" id="MathJax-Element-20">V \leftarrow max(R,G,B)</script>
# </p>
#
# <p class="formulaDsp">
# <span class="MathJax_Preview" style="display: none;"></span><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-21-Frame" tabindex="0" style="text-align: center;"><nobr><span class="math" id="MathJax-Span-369" style="width: 15.883em; display: inline-block;"><span style="display: inline-block; position: relative; width: 13.108em; height: 0px; font-size: 121%;"><span style="position: absolute; clip: rect(2.187em, 1013.11em, 5.611em, -999.997em); top: -4.129em; left: 0em;"><span class="mrow" id="MathJax-Span-370"><span class="mi" id="MathJax-Span-371" style="font-family: STIXGeneral-Italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-372" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">←</span><span class="mrow" id="MathJax-Span-373" style="padding-left: 0.298em;"><span class="mo" id="MathJax-Span-374" style="vertical-align: -0.764em;"><span style="font-family: STIXSizeFourSym;">{</span></span><span class="mtable" id="MathJax-Span-375" style="padding-right: 0.18em; padding-left: 0.18em;"><span style="display: inline-block; position: relative; width: 9.625em; height: 0px;"><span style="position: absolute; clip: rect(2.128em, 1004.61em, 5.198em, -999.997em); top: -4.011em; left: 0em;"><span style="display: inline-block; position: relative; width: 4.607em; height: 0px;"><span style="position: absolute; clip: rect(2.836em, 1004.61em, 4.607em, -999.997em); top: -4.661em; left: 0em;"><span class="mtd" id="MathJax-Span-376"><span class="mrow" id="MathJax-Span-377"><span class="mfrac" id="MathJax-Span-378"><span style="display: inline-block; position: relative; width: 4.371em; height: 0px; margin-right: 0.121em; margin-left: 0.121em;"><span style="position: absolute; clip: rect(3.368em, 1004.19em, 4.312em, -999.997em); top: -4.543em; left: 50%; margin-left: -2.122em;"><span class="mrow" id="MathJax-Span-379"><span class="mi" id="MathJax-Span-380" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-381" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">−</span><span class="mi" id="MathJax-Span-382" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">m</span><span class="mi" id="MathJax-Span-383" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">i</span><span class="mi" id="MathJax-Span-384" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">n</span><span class="mo" id="MathJax-Span-385" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">(</span><span class="mi" id="MathJax-Span-386" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">R</span><span class="mo" id="MathJax-Span-387" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">,</span><span class="mi" id="MathJax-Span-388" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">G</span><span class="mo" id="MathJax-Span-389" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">,</span><span class="mi" id="MathJax-Span-390" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">B</span><span class="mo" id="MathJax-Span-391" style="font-size: 70.7%; font-family: STIXGeneral-Regular;">)</span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; clip: rect(3.368em, 1000.48em, 4.194em, -999.997em); top: -3.657em; left: 50%; margin-left: -0.233em;"><span class="mi" id="MathJax-Span-392" style="font-size: 70.7%; font-family: STIXGeneral-Italic;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; clip: rect(0.829em, 1004.37em, 1.243em, -999.997em); top: -1.296em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 4.371em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.066em;"></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; clip: rect(3.191em, 1000.48em, 4.194em, -999.997em); top: -3.008em; left: 0em;"><span class="mtd" id="MathJax-Span-403"><span class="mrow" id="MathJax-Span-404"><span class="mn" id="MathJax-Span-405" style="font-family: STIXGeneral-Regular;">0</span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; clip: rect(2.482em, 1003.9em, 5.198em, -999.997em); top: -4.011em; left: 5.729em;"><span style="display: inline-block; position: relative; width: 3.899em; height: 0px;"><span style="position: absolute; clip: rect(3.132em, 1003.31em, 4.371em, -999.997em); top: -4.661em; left: 0em;"><span class="mtd" id="MathJax-Span-393"><span class="mrow" id="MathJax-Span-394"><span class="mstyle" id="MathJax-Span-395"><span class="mrow" id="MathJax-Span-396"><span class="mtext" id="MathJax-Span-397" style="font-family: STIXGeneral-Regular;">if&nbsp;</span><span class="texatom" id="MathJax-Span-398"><span class="mrow" id="MathJax-Span-399"><span class="mi" id="MathJax-Span-400" style="font-family: STIXGeneral-Italic;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-401" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">≠</span><span class="mn" id="MathJax-Span-402" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">0</span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; clip: rect(3.132em, 1003.9em, 4.194em, -999.997em); top: -3.008em; left: 0em;"><span class="mtd" id="MathJax-Span-406"><span class="mrow" id="MathJax-Span-407"><span class="mstyle" id="MathJax-Span-408"><span class="mrow" id="MathJax-Span-409"><span class="mtext" id="MathJax-Span-410" style="font-family: STIXGeneral-Regular;">otherwise</span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span></span><span class="mo" id="MathJax-Span-411"></span></span></span><span style="display: inline-block; width: 0px; height: 4.135em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.639em; border-left: 0px solid; width: 0px; height: 3.861em;"></span></span></nobr></span></div><script type="math/tex; mode=display" id="MathJax-Element-21">S \leftarrow \fork{\frac{V-min(R,G,B)}{V}}{if \(V \neq 0\)}{0}{otherwise}</script>
# </p>
#
# <p class="formulaDsp">
# <span class="MathJax_Preview" style="display: none;"></span><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-22-Frame" tabindex="0" style="text-align: center;"><nobr><span class="math" id="MathJax-Span-412" style="width: 29.519em; display: inline-block;"><span style="display: inline-block; position: relative; width: 24.383em; height: 0px; font-size: 121%;"><span style="position: absolute; clip: rect(1.302em, 1024.38em, 7.028em, -999.997em); top: -4.424em; left: 0em;"><span class="mrow" id="MathJax-Span-413"><span class="mi" id="MathJax-Span-414" style="font-family: STIXGeneral-Italic;">H<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-415" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">←</span><span class="mrow" id="MathJax-Span-416" style="padding-left: 0.298em;"><span class="mo" id="MathJax-Span-417" style="vertical-align: 2.955em;"><span style="display: inline-block; position: relative; width: 0.652em; height: 0px;"><span style="position: absolute; font-family: STIXSizeOneSym; top: -3.303em; left: 0em;">⎧<span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; font-family: STIXSizeOneSym; top: 1.066em; left: 0em;">⎩<span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; font-family: STIXSizeOneSym; top: -1.119em; left: 0em;">⎨<span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="font-family: STIXSizeOneSym; position: absolute; top: -2.594em; left: 0em;">⎪<span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="font-family: STIXSizeOneSym; position: absolute; top: -1.886em; left: 0em;">⎪<span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="font-family: STIXSizeOneSym; position: absolute; top: -0.41em; left: 0em;">⎪<span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="font-family: STIXSizeOneSym; position: absolute; top: 0.298em; left: 0em;">⎪<span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span></span><span class="mtable" id="MathJax-Span-418" style="padding-right: 0.18em; padding-left: 0.18em;"><span style="display: inline-block; position: relative; width: 21.077em; height: 0px;"><span style="position: absolute; clip: rect(3.014em, 1014.52em, 8.445em, -999.997em); top: -6.018em; left: 0em;"><span style="display: inline-block; position: relative; width: 14.584em; height: 0px;"><span style="position: absolute; clip: rect(3.132em, 1011.87em, 4.371em, -999.997em); top: -6.136em; left: 0em;"><span class="mtd" id="MathJax-Span-419"><span class="mrow" id="MathJax-Span-420"><span class="texatom" id="MathJax-Span-421"><span class="mrow" id="MathJax-Span-422"><span class="mn" id="MathJax-Span-423" style="font-family: STIXGeneral-Regular;">60</span><span class="mo" id="MathJax-Span-424" style="font-family: STIXGeneral-Regular;">(</span><span class="mi" id="MathJax-Span-425" style="font-family: STIXGeneral-Italic;">G</span><span class="mo" id="MathJax-Span-426" style="font-family: STIXGeneral-Regular; padding-left: 0.239em;">−</span><span class="mi" id="MathJax-Span-427" style="font-family: STIXGeneral-Italic; padding-left: 0.239em;">B</span><span class="mo" id="MathJax-Span-428" style="font-family: STIXGeneral-Regular;">)</span></span></span><span class="texatom" id="MathJax-Span-429"><span class="mrow" id="MathJax-Span-430"><span class="mo" id="MathJax-Span-431" style="font-family: STIXGeneral-Regular;">/</span></span></span><span class="texatom" id="MathJax-Span-432"><span class="mrow" id="MathJax-Span-433"><span class="mo" id="MathJax-Span-434" style="font-family: STIXGeneral-Regular;">(</span><span class="mi" id="MathJax-Span-435" style="font-family: STIXGeneral-Italic;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-436" style="font-family: STIXGeneral-Regular; padding-left: 0.239em;">−</span><span class="mi" id="MathJax-Span-437" style="font-family: STIXGeneral-Italic; padding-left: 0.239em;">m</span><span class="mi" id="MathJax-Span-438" style="font-family: STIXGeneral-Italic;">i</span><span class="mi" id="MathJax-Span-439" style="font-family: STIXGeneral-Italic;">n</span><span class="mo" id="MathJax-Span-440" style="font-family: STIXGeneral-Regular;">(</span><span class="mi" id="MathJax-Span-441" style="font-family: STIXGeneral-Italic;">R</span><span class="mo" id="MathJax-Span-442" style="font-family: STIXGeneral-Regular;">,</span><span class="mi" id="MathJax-Span-443" style="font-family: STIXGeneral-Italic; padding-left: 0.18em;">G</span><span class="mo" id="MathJax-Span-444" style="font-family: STIXGeneral-Regular;">,</span><span class="mi" id="MathJax-Span-445" style="font-family: STIXGeneral-Italic; padding-left: 0.18em;">B</span><span class="mo" id="MathJax-Span-446" style="font-family: STIXGeneral-Regular;">)</span><span class="mo" id="MathJax-Span-447" style="font-family: STIXGeneral-Regular;">)</span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; clip: rect(3.132em, 1014.41em, 4.371em, -999.997em); top: -4.661em; left: 0em;"><span class="mtd" id="MathJax-Span-458"><span class="mrow" id="MathJax-Span-459"><span class="texatom" id="MathJax-Span-460"><span class="mrow" id="MathJax-Span-461"><span class="mn" id="MathJax-Span-462" style="font-family: STIXGeneral-Regular;">120</span><span class="mo" id="MathJax-Span-463" style="font-family: STIXGeneral-Regular; padding-left: 0.239em;">+</span><span class="mn" id="MathJax-Span-464" style="font-family: STIXGeneral-Regular; padding-left: 0.239em;">60</span><span class="mo" id="MathJax-Span-465" style="font-family: STIXGeneral-Regular;">(</span><span class="mi" id="MathJax-Span-466" style="font-family: STIXGeneral-Italic;">B</span><span class="mo" id="MathJax-Span-467" style="font-family: STIXGeneral-Regular; padding-left: 0.239em;">−</span><span class="mi" id="MathJax-Span-468" style="font-family: STIXGeneral-Italic; padding-left: 0.239em;">R</span><span class="mo" id="MathJax-Span-469" style="font-family: STIXGeneral-Regular;">)</span></span></span><span class="texatom" id="MathJax-Span-470"><span class="mrow" id="MathJax-Span-471"><span class="mo" id="MathJax-Span-472" style="font-family: STIXGeneral-Regular;">/</span></span></span><span class="texatom" id="MathJax-Span-473"><span class="mrow" id="MathJax-Span-474"><span class="mo" id="MathJax-Span-475" style="font-family: STIXGeneral-Regular;">(</span><span class="mi" id="MathJax-Span-476" style="font-family: STIXGeneral-Italic;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-477" style="font-family: STIXGeneral-Regular; padding-left: 0.239em;">−</span><span class="mi" id="MathJax-Span-478" style="font-family: STIXGeneral-Italic; padding-left: 0.239em;">m</span><span class="mi" id="MathJax-Span-479" style="font-family: STIXGeneral-Italic;">i</span><span class="mi" id="MathJax-Span-480" style="font-family: STIXGeneral-Italic;">n</span><span class="mo" id="MathJax-Span-481" style="font-family: STIXGeneral-Regular;">(</span><span class="mi" id="MathJax-Span-482" style="font-family: STIXGeneral-Italic;">R</span><span class="mo" id="MathJax-Span-483" style="font-family: STIXGeneral-Regular;">,</span><span class="mi" id="MathJax-Span-484" style="font-family: STIXGeneral-Italic; padding-left: 0.18em;">G</span><span class="mo" id="MathJax-Span-485" style="font-family: STIXGeneral-Regular;">,</span><span class="mi" id="MathJax-Span-486" style="font-family: STIXGeneral-Italic; padding-left: 0.18em;">B</span><span class="mo" id="MathJax-Span-487" style="font-family: STIXGeneral-Regular;">)</span><span class="mo" id="MathJax-Span-488" style="font-family: STIXGeneral-Regular;">)</span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; clip: rect(3.132em, 1014.52em, 4.371em, -999.997em); top: -3.244em; left: 0em;"><span class="mtd" id="MathJax-Span-499"><span class="mrow" id="MathJax-Span-500"><span class="texatom" id="MathJax-Span-501"><span class="mrow" id="MathJax-Span-502"><span class="mn" id="MathJax-Span-503" style="font-family: STIXGeneral-Regular;">240</span><span class="mo" id="MathJax-Span-504" style="font-family: STIXGeneral-Regular; padding-left: 0.239em;">+</span><span class="mn" id="MathJax-Span-505" style="font-family: STIXGeneral-Regular; padding-left: 0.239em;">60</span><span class="mo" id="MathJax-Span-506" style="font-family: STIXGeneral-Regular;">(</span><span class="mi" id="MathJax-Span-507" style="font-family: STIXGeneral-Italic;">R</span><span class="mo" id="MathJax-Span-508" style="font-family: STIXGeneral-Regular; padding-left: 0.239em;">−</span><span class="mi" id="MathJax-Span-509" style="font-family: STIXGeneral-Italic; padding-left: 0.239em;">G</span><span class="mo" id="MathJax-Span-510" style="font-family: STIXGeneral-Regular;">)</span></span></span><span class="texatom" id="MathJax-Span-511"><span class="mrow" id="MathJax-Span-512"><span class="mo" id="MathJax-Span-513" style="font-family: STIXGeneral-Regular;">/</span></span></span><span class="texatom" id="MathJax-Span-514"><span class="mrow" id="MathJax-Span-515"><span class="mo" id="MathJax-Span-516" style="font-family: STIXGeneral-Regular;">(</span><span class="mi" id="MathJax-Span-517" style="font-family: STIXGeneral-Italic;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-518" style="font-family: STIXGeneral-Regular; padding-left: 0.239em;">−</span><span class="mi" id="MathJax-Span-519" style="font-family: STIXGeneral-Italic; padding-left: 0.239em;">m</span><span class="mi" id="MathJax-Span-520" style="font-family: STIXGeneral-Italic;">i</span><span class="mi" id="MathJax-Span-521" style="font-family: STIXGeneral-Italic;">n</span><span class="mo" id="MathJax-Span-522" style="font-family: STIXGeneral-Regular;">(</span><span class="mi" id="MathJax-Span-523" style="font-family: STIXGeneral-Italic;">R</span><span class="mo" id="MathJax-Span-524" style="font-family: STIXGeneral-Regular;">,</span><span class="mi" id="MathJax-Span-525" style="font-family: STIXGeneral-Italic; padding-left: 0.18em;">G</span><span class="mo" id="MathJax-Span-526" style="font-family: STIXGeneral-Regular;">,</span><span class="mi" id="MathJax-Span-527" style="font-family: STIXGeneral-Italic; padding-left: 0.18em;">B</span><span class="mo" id="MathJax-Span-528" style="font-family: STIXGeneral-Regular;">)</span><span class="mo" id="MathJax-Span-529" style="font-family: STIXGeneral-Regular;">)</span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; clip: rect(3.191em, 1000.48em, 4.194em, -999.997em); top: -1.768em; left: 0em;"><span class="mtd" id="MathJax-Span-540"><span class="mrow" id="MathJax-Span-541"><span class="mn" id="MathJax-Span-542" style="font-family: STIXGeneral-Regular;">0</span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span><span style="display: inline-block; width: 0px; height: 6.024em;"></span></span><span style="position: absolute; clip: rect(3.073em, 1005.38em, 8.504em, -999.997em); top: -6.077em; left: 15.705em;"><span style="display: inline-block; position: relative; width: 5.375em; height: 0px;"><span style="position: absolute; clip: rect(3.132em, 1003.43em, 4.194em, -999.997em); top: -6.136em; left: 0em;"><span class="mtd" id="MathJax-Span-448"><span class="mrow" id="MathJax-Span-449"><span class="mstyle" id="MathJax-Span-450"><span class="mrow" id="MathJax-Span-451"><span class="mtext" id="MathJax-Span-452" style="font-family: STIXGeneral-Regular;">if&nbsp;</span><span class="texatom" id="MathJax-Span-453"><span class="mrow" id="MathJax-Span-454"><span class="mi" id="MathJax-Span-455" style="font-family: STIXGeneral-Italic;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-456" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">=</span><span class="mi" id="MathJax-Span-457" style="font-family: STIXGeneral-Italic; padding-left: 0.298em;">R</span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; clip: rect(3.132em, 1003.54em, 4.194em, -999.997em); top: -4.661em; left: 0em;"><span class="mtd" id="MathJax-Span-489"><span class="mrow" id="MathJax-Span-490"><span class="mstyle" id="MathJax-Span-491"><span class="mrow" id="MathJax-Span-492"><span class="mtext" id="MathJax-Span-493" style="font-family: STIXGeneral-Regular;">if&nbsp;</span><span class="texatom" id="MathJax-Span-494"><span class="mrow" id="MathJax-Span-495"><span class="mi" id="MathJax-Span-496" style="font-family: STIXGeneral-Italic;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-497" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">=</span><span class="mi" id="MathJax-Span-498" style="font-family: STIXGeneral-Italic; padding-left: 0.298em;">G</span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; clip: rect(3.132em, 1003.43em, 4.194em, -999.997em); top: -3.244em; left: 0em;"><span class="mtd" id="MathJax-Span-530"><span class="mrow" id="MathJax-Span-531"><span class="mstyle" id="MathJax-Span-532"><span class="mrow" id="MathJax-Span-533"><span class="mtext" id="MathJax-Span-534" style="font-family: STIXGeneral-Regular;">if&nbsp;</span><span class="texatom" id="MathJax-Span-535"><span class="mrow" id="MathJax-Span-536"><span class="mi" id="MathJax-Span-537" style="font-family: STIXGeneral-Italic;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-538" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">=</span><span class="mi" id="MathJax-Span-539" style="font-family: STIXGeneral-Italic; padding-left: 0.298em;">B</span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span><span style="position: absolute; clip: rect(3.132em, 1005.38em, 4.194em, -999.997em); top: -1.768em; left: 0em;"><span class="mtd" id="MathJax-Span-543"><span class="mrow" id="MathJax-Span-544"><span class="mstyle" id="MathJax-Span-545"><span class="mrow" id="MathJax-Span-546"><span class="mtext" id="MathJax-Span-547" style="font-family: STIXGeneral-Regular;">if&nbsp;</span><span class="texatom" id="MathJax-Span-548"><span class="mrow" id="MathJax-Span-549"><span class="mi" id="MathJax-Span-550" style="font-family: STIXGeneral-Italic;">R</span><span class="mo" id="MathJax-Span-551" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">=</span><span class="mi" id="MathJax-Span-552" style="font-family: STIXGeneral-Italic; padding-left: 0.298em;">G</span><span class="mo" id="MathJax-Span-553" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">=</span><span class="mi" id="MathJax-Span-554" style="font-family: STIXGeneral-Italic; padding-left: 0.298em;">B</span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.017em;"></span></span></span><span style="display: inline-block; width: 0px; height: 6.083em;"></span></span></span></span><span class="mo" id="MathJax-Span-555"></span></span></span><span style="display: inline-block; width: 0px; height: 4.43em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -2.996em; border-left: 0px solid; width: 0px; height: 6.646em;"></span></span></nobr></span></div><script type="math/tex; mode=display" id="MathJax-Element-22">H \leftarrow \forkfour{{60(G - B)}/{(V-min(R,G,B))}}{if \(V=R\)} {{120+60(B - R)}/{(V-min(R,G,B))}}{if \(V=G\)} {{240+60(R - G)}/{(V-min(R,G,B))}}{if \(V=B\)} {0}{if \(R=G=B\)}</script>
# </p>
#
# <p> If <span class="MathJax_Preview" style="display: none;"></span><span class="MathJax" id="MathJax-Element-23-Frame" tabindex="0" style=""><nobr><span class="math" id="MathJax-Span-556" style="width: 3.073em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.541em; height: 0px; font-size: 121%;"><span style="position: absolute; clip: rect(1.715em, 1002.54em, 2.718em, -999.997em); top: -2.535em; left: 0em;"><span class="mrow" id="MathJax-Span-557"><span class="mi" id="MathJax-Span-558" style="font-family: STIXGeneral-Italic;">H<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-559" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">&lt;</span><span class="mn" id="MathJax-Span-560" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">0</span></span><span style="display: inline-block; width: 0px; height: 2.541em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.068em; border-left: 0px solid; width: 0px; height: 1.004em;"></span></span></nobr></span><script type="math/tex" id="MathJax-Element-23">H<0</script> then <span class="MathJax_Preview" style="display: none;"></span><span class="MathJax" id="MathJax-Element-24-Frame" tabindex="0" style=""><nobr><span class="math" id="MathJax-Span-561" style="width: 6.969em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.729em; height: 0px; font-size: 121%;"><span style="position: absolute; clip: rect(1.656em, 1005.73em, 2.777em, -999.997em); top: -2.535em; left: 0em;"><span class="mrow" id="MathJax-Span-562"><span class="mi" id="MathJax-Span-563" style="font-family: STIXGeneral-Italic;">H<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-564" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">←</span><span class="mi" id="MathJax-Span-565" style="font-family: STIXGeneral-Italic; padding-left: 0.298em;">H<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-566" style="font-family: STIXGeneral-Regular; padding-left: 0.239em;">+</span><span class="mn" id="MathJax-Span-567" style="font-family: STIXGeneral-Regular; padding-left: 0.239em;">360</span></span><span style="display: inline-block; width: 0px; height: 2.541em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.139em; border-left: 0px solid; width: 0px; height: 1.004em;"></span></span></nobr></span><script type="math/tex" id="MathJax-Element-24">H \leftarrow H+360</script> . On output <span class="MathJax_Preview" style="display: none;"></span><span class="MathJax" id="MathJax-Element-25-Frame" tabindex="0" style=""><nobr><span class="math" id="MathJax-Span-568" style="width: 5.139em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.253em; height: 0px; font-size: 121%;"><span style="position: absolute; clip: rect(1.715em, 1004.13em, 2.836em, -999.997em); top: -2.535em; left: 0em;"><span class="mrow" id="MathJax-Span-569"><span class="mn" id="MathJax-Span-570" style="font-family: STIXGeneral-Regular;">0</span><span class="mo" id="MathJax-Span-571" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">≤</span><span class="mi" id="MathJax-Span-572" style="font-family: STIXGeneral-Italic; padding-left: 0.298em;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-573" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">≤</span><span class="mn" id="MathJax-Span-574" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.541em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.211em; border-left: 0px solid; width: 0px; height: 1.075em;"></span></span></nobr></span><script type="math/tex" id="MathJax-Element-25">0 \leq V \leq 1</script>, <span class="MathJax_Preview" style="display: none;"></span><span class="MathJax" id="MathJax-Element-26-Frame" tabindex="0" style=""><nobr><span class="math" id="MathJax-Span-575" style="width: 4.962em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.076em; height: 0px; font-size: 121%;"><span style="position: absolute; clip: rect(1.715em, 1003.96em, 2.836em, -999.997em); top: -2.535em; left: 0em;"><span class="mrow" id="MathJax-Span-576"><span class="mn" id="MathJax-Span-577" style="font-family: STIXGeneral-Regular;">0</span><span class="mo" id="MathJax-Span-578" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">≤</span><span class="mi" id="MathJax-Span-579" style="font-family: STIXGeneral-Italic; padding-left: 0.298em;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-580" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">≤</span><span class="mn" id="MathJax-Span-581" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.541em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.211em; border-left: 0px solid; width: 0px; height: 1.075em;"></span></span></nobr></span><script type="math/tex" id="MathJax-Element-26">0 \leq S \leq 1</script>, <span class="MathJax_Preview" style="display: none;"></span><span class="MathJax" id="MathJax-Element-27-Frame" tabindex="0" style=""><nobr><span class="math" id="MathJax-Span-582" style="width: 6.496em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.375em; height: 0px; font-size: 121%;"><span style="position: absolute; clip: rect(1.656em, 1005.38em, 2.836em, -999.997em); top: -2.535em; left: 0em;"><span class="mrow" id="MathJax-Span-583"><span class="mn" id="MathJax-Span-584" style="font-family: STIXGeneral-Regular;">0</span><span class="mo" id="MathJax-Span-585" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">≤</span><span class="mi" id="MathJax-Span-586" style="font-family: STIXGeneral-Italic; padding-left: 0.298em;">H<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-587" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">≤</span><span class="mn" id="MathJax-Span-588" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">360</span></span><span style="display: inline-block; width: 0px; height: 2.541em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.211em; border-left: 0px solid; width: 0px; height: 1.075em;"></span></span></nobr></span><script type="math/tex" id="MathJax-Element-27">0 \leq H \leq 360</script> .</p>
#
# <p>The values are then converted to the destination data type:</p>
# <ul>
# <li>8-bit images: <span class="MathJax_Preview" style="display: none;"></span><span class="MathJax" id="MathJax-Element-28-Frame" tabindex="0" style=""><nobr><span class="math" id="MathJax-Span-589" style="width: 24.442em; display: inline-block;"><span style="display: inline-block; position: relative; width: 20.192em; height: 0px; font-size: 121%;"><span style="position: absolute; clip: rect(1.656em, 1020.13em, 2.896em, -999.997em); top: -2.535em; left: 0em;"><span class="mrow" id="MathJax-Span-590"><span class="mi" id="MathJax-Span-591" style="font-family: STIXGeneral-Italic;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-592" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">←</span><span class="mn" id="MathJax-Span-593" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">255</span><span class="mi" id="MathJax-Span-594" style="font-family: STIXGeneral-Italic;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-595" style="font-family: STIXGeneral-Regular;">,</span><span class="mi" id="MathJax-Span-596" style="font-family: STIXGeneral-Italic; padding-left: 0.18em;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-597" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">←</span><span class="mn" id="MathJax-Span-598" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">255</span><span class="mi" id="MathJax-Span-599" style="font-family: STIXGeneral-Italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-600" style="font-family: STIXGeneral-Regular;">,</span><span class="mi" id="MathJax-Span-601" style="font-family: STIXGeneral-Italic; padding-left: 0.18em;">H<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-602" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">←</span><span class="mi" id="MathJax-Span-603" style="font-family: STIXGeneral-Italic; padding-left: 0.298em;">H<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="texatom" id="MathJax-Span-604"><span class="mrow" id="MathJax-Span-605"><span class="mo" id="MathJax-Span-606" style="font-family: STIXGeneral-Regular;">/</span></span></span><span class="mn" id="MathJax-Span-607" style="font-family: STIXGeneral-Regular;">2</span><span class="mtext" id="MathJax-Span-608" style="font-family: STIXGeneral-Regular;">(to fit to 0 to 255)</span></span><span style="display: inline-block; width: 0px; height: 2.541em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 1.218em;"></span></span></nobr></span><script type="math/tex" id="MathJax-Element-28">V \leftarrow 255 V, S \leftarrow 255 S, H \leftarrow H/2 \text{(to fit to 0 to 255)}</script></li>
# <li>16-bit images: (currently not supported) <span class="MathJax_Preview" style="display: none;"></span><span class="MathJax" id="MathJax-Element-29-Frame" tabindex="0" style=""><nobr><span class="math" id="MathJax-Span-609" style="width: 19.011em; display: inline-block;"><span style="display: inline-block; position: relative; width: 15.705em; height: 0px; font-size: 121%;"><span style="position: absolute; clip: rect(1.656em, 1015.71em, 2.836em, -999.997em); top: -2.535em; left: 0em;"><span class="mrow" id="MathJax-Span-610"><span class="mi" id="MathJax-Span-611" style="font-family: STIXGeneral-Italic;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-612" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">&lt;</span><span class="mo" id="MathJax-Span-613" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">−</span><span class="mn" id="MathJax-Span-614" style="font-family: STIXGeneral-Regular;">65535</span><span class="mi" id="MathJax-Span-615" style="font-family: STIXGeneral-Italic;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-616" style="font-family: STIXGeneral-Regular;">,</span><span class="mi" id="MathJax-Span-617" style="font-family: STIXGeneral-Italic; padding-left: 0.18em;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-618" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">&lt;</span><span class="mo" id="MathJax-Span-619" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">−</span><span class="mn" id="MathJax-Span-620" style="font-family: STIXGeneral-Regular;">65535</span><span class="mi" id="MathJax-Span-621" style="font-family: STIXGeneral-Italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-622" style="font-family: STIXGeneral-Regular;">,</span><span class="mi" id="MathJax-Span-623" style="font-family: STIXGeneral-Italic; padding-left: 0.18em;">H<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span><span class="mo" id="MathJax-Span-624" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">&lt;</span><span class="mo" id="MathJax-Span-625" style="font-family: STIXGeneral-Regular; padding-left: 0.298em;">−</span><span class="mi" id="MathJax-Span-626" style="font-family: STIXGeneral-Italic;">H<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.062em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.541em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.211em; border-left: 0px solid; width: 0px; height: 1.146em;"></span></span></nobr></span><script type="math/tex" id="MathJax-Element-29">V <- 65535 V, S <- 65535 S, H <- H</script></li>
# <li>32-bit images: H, S, and V are left as is</li>
# </ul>
# <p>

# %% [markdown]
# [Open CV RGB -> HSB](https://docs.opencv.org/3.4/de/d25/imgproc_color_conversions.html#color_convert_rgb_hsv)

# %%
import numpy as np

def rgb_to_hsb(rgb):
    # rgb is an 1-D array [r,g,b] r = rgb[0], b = rgb[1], g = rgb[2]

    # Floating point values between 0 - 1
    rgb = rgb/255

    # Initialize HSB 
    h = 0.0
    s = 0.0
    b = 0.0

    # Find the max and min RGB values. 
    v = np.max(rgb)
    vMin = np.min(rgb)

    # Set the saturation value.
    if(v>0.0):
        s = (v - vMin)/v
    else:
        s = 0.0

    # Calculate (v - vMin) convenience
    diff = (v - vMin)

    # Compute the hue by the relative sizes of the RGB components

    # Is the point within +/- 60 degrees of the red axis
    if(rgb[0] == v):
        h = 60 * (rgb[1] - rgb[2]) / diff
    # Is the point within +/- 60 degrees of the greed axis
    elif(rgb[1] == v):
        h = 120 + 60 * (rgb[2] - rgb[0]) / diff
    # IS the point within +/- 60 degrees of the blue axis
    elif(rgb[2] == v):
        h = 240 + 60 * (rgb[0] - rgb[1]) / diff
    # Are r,g,b equal. 
    elif(rgb[0] == rgb[1] and rgb[1] == rgb[2]):
        h = 0

    return np.array([h,s,v])

rgb = np.array([200,74,55])
hsv = rgb_to_hsb(rgb)

print("The original rgb value:", rgb)
print("Converted to hsv:", hsv)
# Out:
# The original rgb value: [200  74  55]
# Converted to hsv: [7.86206897 0.725      0.78431373]

# %% [markdown]
# **YCrCb, YCbCr, ...**
#
# Is primary a broadcast color space.  It's main advantage is in compression and subsampling.  Will be discussed more in Image Compression Module 3a<br>
# +  The Y stands for the Luma value (Brightness) or the image.  <br>
# + Cr stands for the change in the red channel.<br>
# + Cb stands for the change in the blue channel. <br>
#
#
#
# [YCrCb wiki](https://en.wikipedia.org/wiki/YCbCr)

# %% [markdown]
# ## Common File Types
#
# ### **Raster**  (Pixel Array)
#
# The raster file formats all store image data in an array structure.  Different formats allow for certain types of compression, color spaces, and bit depth.  Separating formats into lossy and lossless.
#
# + **TIFF** Tag Image File Format. (1986)  Orginated by the Aldus Corp and later bought by Adobe.  Tiff or Tif is very general and complex format.  Cross platform compatible.  Can store both lossy (Jpeg) and lossless image data.
# [TIFF Wiki](https://en.wikipedia.org/wiki/TIFF) <br><br>
# + **JPEG**  (JPG) Joint Photographic Experts Group. (1992)  Jpeg's main advantage is high-quality practical compression. [JPEG Wiki](https://en.wikipedia.org/wiki/JPEG)<br><br>
# + **GIF**  The General Graphics Interchange Format. (1987)  Color must be represented in 8-bits total for all color channels so limited to 256 colors. 16-bit option also available but the 8-bit is most popular.  The limited file size and ability to store multiple images in one file made the format popular in the early days of the internet to today. [GIF Wiki](https://en.wikipedia.org/wiki/GIF) <br><br>
# + **PNG** Portable Network Graphics. (1996) PNG Working Group and donated to W3. Designed as a replacement for the GIF.  Lossless compression RGB 24-bit color.[PNG Wiki](https://en.wikipedia.org/wiki/Portable_Network_Graphics)

# %% [markdown]
# ### **Vector**
#
# The vector files formats are built using coded lines and angles to draw images, type, graphics.
#
# + **Postscript** Page Description Language. (1982)  Invented by Adobe.  PDF, EPS.  Dominates the graphics and printing industry. [Postscript Wiki](https://en.wikipedia.org/wiki/PostScript)<br><br>
# + **SVG**  Scalable Vector Graphics. (1999) World Wide Web Consortium (W3C)  Vector graphics stored in XML files which allows easy searching.  Allows for multiple files and animation. [SVG Wiki](https://en.wikipedia.org/wiki/Scalable_Vector_Graphics)
