# %% [markdown]
# # Module 2: Stepping Through An Image
#
# "The basic technical distinction between analog(continous) and digital(discrete) representations is crucial(...)&ndash;  Rolling down a ramp is continous motion, but walking down stairs is a sequence of discrete steps&ndash;so you can count the number of steps, but not the number of levels on the ramp." &ndash; William Mitchell (The Reconfigured Eye)
# ****

# %% [markdown]
# ### The Discrete Digital World
#
# In the previous Module we examined a 200 x 200 digital image with a total of 40,000 individual pixels.  This is a key point to understand as we move into searching, transforming, and making predictions from digital image data. We can add more and more pixels to our grid to increase the resolution of our image but it will always have a set upper limit.  In our case this will be 40,000. There is never a fraction or negative value assigned to a pixel.  We are dealing only with whole numbers or non-negative real numbers.  The discrete nature of our data allows us to step through each individual pixel performing whichever operation is desired.
#
# First let's draw our image.

# %%
#Install Open CV and give tutorial on getting Jupyter notebook up and running.
# %pip install opencv-contrib-python
# %pip install matplotlib

#Import Libraries
import cv2
import numpy as np
import copy
import matplotlib.pyplot as plt

#Saving the image in a variable
img = cv2.imread('../Graphics/face.png')

#OpenCV by defualt uses BGR instead of RGB.  Old digital camera standard.
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#Use matplotlib while using a python notebook. Draw the image.
plt.imshow(img)

# %% [markdown]
# ### The Step
#
# To step through all the pixel values we need a control statement to tell the computer which values to iterate through.
#
# If the values are in a 2D array we would want the following statment:<p>
#
# + For each row in our grid.<br>
# + Visit each pixel in the row. <br>
#
# A **For Loop** is the perfect programming tool to use for this statement.  A for loop requires three pieces of information: the data you want it to itereate through, the index to start at, and the index to end at.
#
# In Python we write a for loop in the following manner:
#
# for ***data*** in range(***starting index***, ***ending index***):
#
# Examining our statement we need to iterate through both the rows and individual pixels.  So we need two for loops to accomplish this statement.  This is called a **nested for loop**.
#
# Sudo Code:<br>
# For each row in our grid.<br>
# Visit each pixel in the row. <br>
#
# Python:<br>
# for row in range(0, height):<br>
# &nbsp;&nbsp;&nbsp;&nbsp;for pixel in range(0, width):<br>
#
# Notice the spacing in the Python code.  A tab is used to indicate that one for loop is nested inside the other for loop.
#
# The row is the first dimension in our array and the pixel is the second dimension.
#
# image[row][pixel]
#
# Let's use a nested for loop to step through all the pixels in our image.

# %%
#Stepping through the image.

#Save the height and width.
h = img.shape[0]
w = img.shape[1]
d = img.shape[2]

#A counting variable so we can keep track how many values we have.
count = 0

#Let's step through each pixel

#For each row in our grid. y = row
for y in range(0,h):
    #Search each pixel in the row. x = pixel
    for x in range(0,w):
       count+=1

#Print the total number of pixels. 200x200 = 40000
print(count)

#Reintialize the counting variable
count = 0

#Let's step through each RBG value.

#For each row in our grid. y = row
for y in range(0,h):
    #Search each pixel in the row. x = pixel
    for x in range(0,w):
        #Search each RGB value.
        for z in range(0,d):
             count+=1

#Print the total number of RGB values. 200x200x3 = 120000   
print(count)
# Out:
# 40000
# 120000

# %% [markdown]
# Let's search for black and white pixels in our image.

# %%
#Loop through the pixel array testing if the pixel is white.

#Save the height and width.
h = img.shape[0]
w = img.shape[1]

#Save the the RGB vales for white & black.
white = np.array([255,255,255])
black = np.array([0,0,0])

#A counting variable so we can keep track how many values we have.
count = 0

#For each row in our grid. y = row
for y in range(0,h):
    #Search each pixel in the row. x = pixel
    for x in range(0,w):
        #If the RGB values equal white.
        if np.array_equal(img[y,x],white):
            #Print the 2D array location.  
            print("Pixel [",y,"]","[",x,"]", "is the color white.")
            #Increase the counting variable
            count+=1

#Print the total number of white pixels. 
print("There are",count,"white pixels.")
# Out:
# Pixel [ 88 ] [ 88 ] is the color white.
# Pixel [ 92 ] [ 145 ] is the color white.
# Pixel [ 102 ] [ 186 ] is the color white.
# Pixel [ 168 ] [ 185 ] is the color white.
# Pixel [ 179 ] [ 183 ] is the color white.
# There are 5 white pixels.

# %%
#Now let's test for black pixels.

#Set our count variable to zero.
count = 0

#For each row in our grid.
for y in range(0,h):
    #Search each pixel in the row.
    for x in range(0,w):
        #If the RGB values equal white.
        if np.array_equal(img[y,x],black):
            #Print the 2D array location.
            print("Pixel [",y,"]","[",x,"]", "is the color black.")
            #Increase the counting variable.
            count+=1

#Print the total number of black pixels.
print("There are",count,"black pixels.")
# Out:
# Pixel [ 0 ] [ 128 ] is the color black.
# Pixel [ 1 ] [ 119 ] is the color black.
# Pixel [ 1 ] [ 143 ] is the color black.
# Pixel [ 2 ] [ 91 ] is the color black.
# Pixel [ 2 ] [ 143 ] is the color black.
# Pixel [ 2 ] [ 144 ] is the color black.
# Pixel [ 3 ] [ 144 ] is the color black.
# Pixel [ 4 ] [ 41 ] is the color black.
# Pixel [ 4 ] [ 93 ] is the color black.
# Pixel [ 4 ] [ 109 ] is the color black.
# Pixel [ 4 ] [ 141 ] is the color black.
# Pixel [ 4 ] [ 144 ] is the color black.
# Pixel [ 5 ] [ 38 ] is the color black.
# Pixel [ 5 ] [ 84 ] is the color black.
# Pixel [ 5 ] [ 88 ] is the color black.
# Pixel [ 5 ] [ 105 ] is the color black.
# Pixel [ 5 ] [ 145 ] is the color black.
# Pixel [ 6 ] [ 89 ] is the color black.
# Pixel [ 6 ] [ 121 ] is the color black.
# Pixel [ 6 ] [ 146 ] is the color black.
# Pixel [ 7 ] [ 19 ] is the color black.
# Pixel [ 7 ] [ 86 ] is the color black.
# Pixel [ 7 ] [ 90 ] is the color black.
# Pixel [ 7 ] [ 96 ] is the color black.
# Pixel [ 7 ] [ 146 ] is the color black.
# Pixel [ 8 ] [ 111 ] is the color black.
# Pixel [ 8 ] [ 130 ] is the color black.
# Pixel [ 8 ] [ 146 ] is the color black.
# Pixel [ 9 ] [ 130 ] is the color black.
# Pixel [ 9 ] [ 147 ] is the color black.
# Pixel [ 10 ] [ 16 ] is the color black.
# Pixel [ 10 ] [ 92 ] is the color black.
# Pixel [ 10 ] [ 145 ] is the color black.
# Pixel [ 10 ] [ 148 ] is the color black.
# Pixel [ 11 ] [ 15 ] is the color black.
# Pixel [ 11 ] [ 131 ] is the color black.
# Pixel [ 11 ] [ 148 ] is the color black.
# Pixel [ 12 ] [ 19 ] is the color black.
# Pixel [ 12 ] [ 149 ] is the color black.
# Pixel [ 13 ] [ 4 ] is the color black.
# Pixel [ 13 ] [ 70 ] is the color black.
# Pixel [ 13 ] [ 149 ] is the color black.
# Pixel [ 14 ] [ 3 ] is the color black.
# Pixel [ 15 ] [ 2 ] is the color black.
# Pixel [ 15 ] [ 62 ] is the color black.
# Pixel [ 15 ] [ 76 ] is the color black.
# Pixel [ 15 ] [ 150 ] is the color black.
# Pixel [ 16 ] [ 1 ] is the color black.
# Pixel [ 16 ] [ 81 ] is the color black.
# Pixel [ 16 ] [ 94 ] is the color black.
# Pixel [ 16 ] [ 151 ] is the color black.
# Pixel [ 17 ] [ 80 ] is the color black.
# Pixel [ 17 ] [ 151 ] is the color black.
# Pixel [ 18 ] [ 138 ] is the color black.
# Pixel [ 18 ] [ 151 ] is the color black.
# Pixel [ 19 ] [ 84 ] is the color black.
# Pixel [ 19 ] [ 89 ] is the color black.
# Pixel [ 19 ] [ 122 ] is the color black.
# Pixel [ 19 ] [ 152 ] is the color black.
# Pixel [ 20 ] [ 81 ] is the color black.
# Pixel [ 20 ] [ 127 ] is the color black.
# Pixel [ 20 ] [ 152 ] is the color black.
# Pixel [ 21 ] [ 152 ] is the color black.
# Pixel [ 22 ] [ 152 ] is the color black.
# Pixel [ 23 ] [ 130 ] is the color black.
# Pixel [ 23 ] [ 140 ] is the color black.
# Pixel [ 23 ] [ 153 ] is the color black.
# Pixel [ 24 ] [ 150 ] is the color black.
# Pixel [ 24 ] [ 152 ] is the color black.
# Pixel [ 26 ] [ 138 ] is the color black.
# Pixel [ 26 ] [ 153 ] is the color black.
# Pixel [ 26 ] [ 154 ] is the color black.
# Pixel [ 27 ] [ 132 ] is the color black.
# Pixel [ 27 ] [ 154 ] is the color black.
# Pixel [ 28 ] [ 133 ] is the color black.
# Pixel [ 28 ] [ 134 ] is the color black.
# Pixel [ 28 ] [ 152 ] is the color black.
# Pixel [ 29 ] [ 125 ] is the color black.
# Pixel [ 29 ] [ 153 ] is the color black.
# Pixel [ 29 ] [ 155 ] is the color black.
# Pixel [ 30 ] [ 47 ] is the color black.
# Pixel [ 30 ] [ 153 ] is the color black.
# Pixel [ 30 ] [ 155 ] is the color black.
# Pixel [ 32 ] [ 45 ] is the color black.
# Pixel [ 32 ] [ 126 ] is the color black.
# Pixel [ 32 ] [ 154 ] is the color black.
# Pixel [ 32 ] [ 155 ] is the color black.
# Pixel [ 32 ] [ 156 ] is the color black.
# Pixel [ 33 ] [ 136 ] is the color black.
# Pixel [ 34 ] [ 136 ] is the color black.
# Pixel [ 35 ] [ 137 ] is the color black.
# Pixel [ 35 ] [ 154 ] is the color black.
# Pixel [ 35 ] [ 155 ] is the color black.
# Pixel [ 36 ] [ 157 ] is the color black.
# Pixel [ 37 ] [ 158 ] is the color black.
# Pixel [ 37 ] [ 159 ] is the color black.
# Pixel [ 38 ] [ 160 ] is the color black.
# Pixel [ 39 ] [ 157 ] is the color black.
# Pixel [ 40 ] [ 158 ] is the color black.
# Pixel [ 41 ] [ 138 ] is the color black.
# Pixel [ 41 ] [ 139 ] is the color black.
# Pixel [ 42 ] [ 138 ] is the color black.
# Pixel [ 42 ] [ 139 ] is the color black.
# Pixel [ 42 ] [ 159 ] is the color black.
# Pixel [ 42 ] [ 162 ] is the color black.
# Pixel [ 43 ] [ 140 ] is the color black.
# Pixel [ 43 ] [ 160 ] is the color black.
# Pixel [ 44 ] [ 12 ] is the color black.
# Pixel [ 44 ] [ 32 ] is the color black.
# Pixel [ 44 ] [ 59 ] is the color black.
# Pixel [ 44 ] [ 136 ] is the color black.
# Pixel [ 44 ] [ 161 ] is the color black.
# Pixel [ 45 ] [ 159 ] is the color black.
# Pixel [ 46 ] [ 50 ] is the color black.
# Pixel [ 46 ] [ 141 ] is the color black.
# Pixel [ 46 ] [ 160 ] is the color black.
# Pixel [ 47 ] [ 142 ] is the color black.
# Pixel [ 47 ] [ 161 ] is the color black.
# Pixel [ 47 ] [ 164 ] is the color black.
# Pixel [ 48 ] [ 165 ] is the color black.
# Pixel [ 50 ] [ 166 ] is the color black.
# Pixel [ 51 ] [ 167 ] is the color black.
# Pixel [ 55 ] [ 167 ] is the color black.
# Pixel [ 55 ] [ 168 ] is the color black.
# Pixel [ 57 ] [ 46 ] is the color black.
# Pixel [ 57 ] [ 168 ] is the color black.
# Pixel [ 58 ] [ 41 ] is the color black.
# Pixel [ 58 ] [ 42 ] is the color black.
# Pixel [ 58 ] [ 169 ] is the color black.
# Pixel [ 59 ] [ 40 ] is the color black.
# Pixel [ 59 ] [ 166 ] is the color black.
# Pixel [ 59 ] [ 170 ] is the color black.
# Pixel [ 60 ] [ 167 ] is the color black.
# Pixel [ 60 ] [ 171 ] is the color black.
# Pixel [ 61 ] [ 36 ] is the color black.
# Pixel [ 61 ] [ 156 ] is the color black.
# Pixel [ 61 ] [ 167 ] is the color black.
# Pixel [ 62 ] [ 157 ] is the color black.
# Pixel [ 62 ] [ 169 ] is the color black.
# Pixel [ 63 ] [ 158 ] is the color black.
# Pixel [ 63 ] [ 159 ] is the color black.
# Pixel [ 65 ] [ 160 ] is the color black.
# Pixel [ 66 ] [ 161 ] is the color black.
# Pixel [ 66 ] [ 174 ] is the color black.
# Pixel [ 67 ] [ 162 ] is the color black.
# Pixel [ 69 ] [ 1 ] is the color black.
# Pixel [ 70 ] [ 33 ] is the color black.
# Pixel [ 72 ] [ 38 ] is the color black.
# Pixel [ 73 ] [ 38 ] is the color black.
# Pixel [ 73 ] [ 170 ] is the color black.
# Pixel [ 74 ] [ 32 ] is the color black.
# Pixel [ 74 ] [ 62 ] is the color black.
# Pixel [ 74 ] [ 164 ] is the color black.
# Pixel [ 75 ] [ 10 ] is the color black.
# Pixel [ 75 ] [ 27 ] is the color black.
# Pixel [ 75 ] [ 32 ] is the color black.
# Pixel [ 76 ] [ 20 ] is the color black.
# Pixel [ 76 ] [ 36 ] is the color black.
# Pixel [ 78 ] [ 29 ] is the color black.
# Pixel [ 78 ] [ 35 ] is the color black.
# Pixel [ 80 ] [ 31 ] is the color black.
# Pixel [ 80 ] [ 34 ] is the color black.
# Pixel [ 81 ] [ 160 ] is the color black.
# Pixel [ 81 ] [ 163 ] is the color black.
# Pixel [ 82 ] [ 28 ] is the color black.
# Pixel [ 82 ] [ 33 ] is the color black.
# Pixel [ 82 ] [ 71 ] is the color black.
# Pixel [ 82 ] [ 76 ] is the color black.
# Pixel [ 83 ] [ 76 ] is the color black.
# Pixel [ 83 ] [ 77 ] is the color black.
# Pixel [ 83 ] [ 78 ] is the color black.
# Pixel [ 84 ] [ 73 ] is the color black.
# Pixel [ 84 ] [ 74 ] is the color black.
# Pixel [ 84 ] [ 75 ] is the color black.
# Pixel [ 84 ] [ 76 ] is the color black.
# Pixel [ 86 ] [ 28 ] is the color black.
# Pixel [ 86 ] [ 68 ] is the color black.
# Pixel [ 86 ] [ 69 ] is the color black.
# Pixel [ 86 ] [ 70 ] is the color black.
# Pixel [ 86 ] [ 85 ] is the color black.
# Pixel [ 86 ] [ 97 ] is the color black.
# Pixel [ 87 ] [ 2 ] is the color black.
# Pixel [ 87 ] [ 143 ] is the color black.
# Pixel [ 87 ] [ 144 ] is the color black.
# Pixel [ 87 ] [ 145 ] is the color black.
# Pixel [ 88 ] [ 93 ] is the color black.
# Pixel [ 88 ] [ 146 ] is the color black.
# Pixel [ 88 ] [ 147 ] is the color black.
# Pixel [ 88 ] [ 148 ] is the color black.
# Pixel [ 89 ] [ 148 ] is the color black.
# Pixel [ 89 ] [ 149 ] is the color black.
# Pixel [ 90 ] [ 150 ] is the color black.
# Pixel [ 90 ] [ 164 ] is the color black.
# Pixel [ 90 ] [ 180 ] is the color black.
# Pixel [ 91 ] [ 151 ] is the color black.
# Pixel [ 91 ] [ 152 ] is the color black.
# Pixel [ 91 ] [ 163 ] is the color black.
# Pixel [ 92 ] [ 25 ] is the color black.
# Pixel [ 92 ] [ 84 ] is the color black.
# Pixel [ 92 ] [ 152 ] is the color black.
# Pixel [ 92 ] [ 161 ] is the color black.
# Pixel [ 93 ] [ 153 ] is the color black.
# Pixel [ 94 ] [ 1 ] is the color black.
# Pixel [ 94 ] [ 155 ] is the color black.
# Pixel [ 98 ] [ 4 ] is the color black.
# Pixel [ 98 ] [ 5 ] is the color black.
# Pixel [ 98 ] [ 28 ] is the color black.
# Pixel [ 98 ] [ 161 ] is the color black.
# Pixel [ 102 ] [ 182 ] is the color black.
# Pixel [ 103 ] [ 8 ] is the color black.
# Pixel [ 104 ] [ 8 ] is the color black.
# Pixel [ 104 ] [ 161 ] is the color black.
# Pixel [ 105 ] [ 7 ] is the color black.
# Pixel [ 105 ] [ 160 ] is the color black.
# Pixel [ 106 ] [ 10 ] is the color black.
# Pixel [ 106 ] [ 160 ] is the color black.
# Pixel [ 106 ] [ 167 ] is the color black.
# Pixel [ 106 ] [ 168 ] is the color black.
# Pixel [ 107 ] [ 160 ] is the color black.
# Pixel [ 108 ] [ 2 ] is the color black.
# Pixel [ 108 ] [ 7 ] is the color black.
# Pixel [ 108 ] [ 12 ] is the color black.
# Pixel [ 108 ] [ 22 ] is the color black.
# Pixel [ 108 ] [ 160 ] is the color black.
# Pixel [ 109 ] [ 23 ] is the color black.
# Pixel [ 109 ] [ 160 ] is the color black.
# Pixel [ 109 ] [ 168 ] is the color black.
# Pixel [ 110 ] [ 23 ] is the color black.
# Pixel [ 110 ] [ 160 ] is the color black.
# Pixel [ 111 ] [ 23 ] is the color black.
# Pixel [ 111 ] [ 160 ] is the color black.
# Pixel [ 112 ] [ 21 ] is the color black.
# Pixel [ 112 ] [ 169 ] is the color black.
# Pixel [ 114 ] [ 25 ] is the color black.
# Pixel [ 116 ] [ 23 ] is the color black.
# Pixel [ 117 ] [ 26 ] is the color black.
# Pixel [ 120 ] [ 8 ] is the color black.
# Pixel [ 121 ] [ 13 ] is the color black.
# Pixel [ 122 ] [ 13 ] is the color black.
# Pixel [ 123 ] [ 19 ] is the color black.
# Pixel [ 123 ] [ 157 ] is the color black.
# Pixel [ 124 ] [ 12 ] is the color black.
# Pixel [ 125 ] [ 156 ] is the color black.
# Pixel [ 130 ] [ 154 ] is the color black.
# Pixel [ 131 ] [ 2 ] is the color black.
# Pixel [ 131 ] [ 154 ] is the color black.
# Pixel [ 132 ] [ 1 ] is the color black.
# Pixel [ 132 ] [ 11 ] is the color black.
# Pixel [ 132 ] [ 21 ] is the color black.
# Pixel [ 133 ] [ 12 ] is the color black.
# Pixel [ 133 ] [ 153 ] is the color black.
# Pixel [ 134 ] [ 9 ] is the color black.
# Pixel [ 134 ] [ 12 ] is the color black.
# Pixel [ 135 ] [ 9 ] is the color black.
# Pixel [ 135 ] [ 10 ] is the color black.
# Pixel [ 135 ] [ 13 ] is the color black.
# Pixel [ 135 ] [ 23 ] is the color black.
# Pixel [ 135 ] [ 28 ] is the color black.
# Pixel [ 135 ] [ 152 ] is the color black.
# Pixel [ 136 ] [ 5 ] is the color black.
# Pixel [ 136 ] [ 10 ] is the color black.
# Pixel [ 136 ] [ 13 ] is the color black.
# Pixel [ 136 ] [ 23 ] is the color black.
# Pixel [ 138 ] [ 151 ] is the color black.
# Pixel [ 140 ] [ 32 ] is the color black.
# Pixel [ 140 ] [ 150 ] is the color black.
# Pixel [ 141 ] [ 149 ] is the color black.
# Pixel [ 142 ] [ 149 ] is the color black.
# Pixel [ 143 ] [ 16 ] is the color black.
# Pixel [ 143 ] [ 34 ] is the color black.
# Pixel [ 143 ] [ 148 ] is the color black.
# Pixel [ 144 ] [ 148 ] is the color black.
# Pixel [ 145 ] [ 36 ] is the color black.
# Pixel [ 145 ] [ 147 ] is the color black.
# Pixel [ 146 ] [ 35 ] is the color black.
# Pixel [ 147 ] [ 12 ] is the color black.
# Pixel [ 147 ] [ 146 ] is the color black.
# Pixel [ 148 ] [ 13 ] is the color black.
# Pixel [ 148 ] [ 145 ] is the color black.
# Pixel [ 149 ] [ 16 ] is the color black.
# Pixel [ 149 ] [ 17 ] is the color black.
# Pixel [ 150 ] [ 20 ] is the color black.
# Pixel [ 150 ] [ 21 ] is the color black.
# Pixel [ 150 ] [ 144 ] is the color black.
# Pixel [ 151 ] [ 24 ] is the color black.
# Pixel [ 151 ] [ 25 ] is the color black.
# Pixel [ 151 ] [ 143 ] is the color black.
# Pixel [ 152 ] [ 27 ] is the color black.
# Pixel [ 152 ] [ 28 ] is the color black.
# Pixel [ 152 ] [ 29 ] is the color black.
# Pixel [ 152 ] [ 30 ] is the color black.
# Pixel [ 152 ] [ 33 ] is the color black.
# Pixel [ 152 ] [ 143 ] is the color black.
# Pixel [ 153 ] [ 28 ] is the color black.
# Pixel [ 153 ] [ 29 ] is the color black.
# Pixel [ 153 ] [ 36 ] is the color black.
# Pixel [ 153 ] [ 142 ] is the color black.
# Pixel [ 154 ] [ 37 ] is the color black.
# Pixel [ 154 ] [ 41 ] is the color black.
# Pixel [ 155 ] [ 38 ] is the color black.
# Pixel [ 155 ] [ 39 ] is the color black.
# Pixel [ 155 ] [ 40 ] is the color black.
# Pixel [ 155 ] [ 41 ] is the color black.
# Pixel [ 155 ] [ 141 ] is the color black.
# Pixel [ 156 ] [ 42 ] is the color black.
# Pixel [ 156 ] [ 43 ] is the color black.
# Pixel [ 156 ] [ 140 ] is the color black.
# Pixel [ 157 ] [ 44 ] is the color black.
# Pixel [ 157 ] [ 45 ] is the color black.
# Pixel [ 158 ] [ 46 ] is the color black.
# Pixel [ 158 ] [ 139 ] is the color black.
# Pixel [ 159 ] [ 47 ] is the color black.
# Pixel [ 161 ] [ 49 ] is the color black.
# Pixel [ 162 ] [ 50 ] is the color black.
# Pixel [ 163 ] [ 51 ] is the color black.
# Pixel [ 164 ] [ 52 ] is the color black.
# Pixel [ 165 ] [ 52 ] is the color black.
# Pixel [ 166 ] [ 53 ] is the color black.
# Pixel [ 166 ] [ 133 ] is the color black.
# Pixel [ 167 ] [ 53 ] is the color black.
# Pixel [ 168 ] [ 54 ] is the color black.
# Pixel [ 169 ] [ 55 ] is the color black.
# Pixel [ 170 ] [ 56 ] is the color black.
# Pixel [ 170 ] [ 130 ] is the color black.
# Pixel [ 171 ] [ 56 ] is the color black.
# Pixel [ 171 ] [ 57 ] is the color black.
# Pixel [ 172 ] [ 57 ] is the color black.
# Pixel [ 173 ] [ 58 ] is the color black.
# Pixel [ 173 ] [ 128 ] is the color black.
# Pixel [ 174 ] [ 127 ] is the color black.
# Pixel [ 175 ] [ 59 ] is the color black.
# Pixel [ 175 ] [ 126 ] is the color black.
# Pixel [ 176 ] [ 60 ] is the color black.
# Pixel [ 176 ] [ 62 ] is the color black.
# Pixel [ 176 ] [ 125 ] is the color black.
# Pixel [ 177 ] [ 61 ] is the color black.
# Pixel [ 177 ] [ 63 ] is the color black.
# Pixel [ 177 ] [ 124 ] is the color black.
# Pixel [ 178 ] [ 123 ] is the color black.
# Pixel [ 179 ] [ 63 ] is the color black.
# Pixel [ 179 ] [ 65 ] is the color black.
# Pixel [ 179 ] [ 66 ] is the color black.
# Pixel [ 179 ] [ 123 ] is the color black.
# Pixel [ 180 ] [ 67 ] is the color black.
# Pixel [ 180 ] [ 122 ] is the color black.
# Pixel [ 181 ] [ 68 ] is the color black.
# Pixel [ 181 ] [ 121 ] is the color black.
# Pixel [ 182 ] [ 70 ] is the color black.
# Pixel [ 185 ] [ 73 ] is the color black.
# Pixel [ 185 ] [ 118 ] is the color black.
# Pixel [ 186 ] [ 74 ] is the color black.
# Pixel [ 186 ] [ 75 ] is the color black.
# Pixel [ 186 ] [ 117 ] is the color black.
# Pixel [ 187 ] [ 71 ] is the color black.
# Pixel [ 187 ] [ 76 ] is the color black.
# Pixel [ 188 ] [ 115 ] is the color black.
# Pixel [ 189 ] [ 72 ] is the color black.
# Pixel [ 189 ] [ 73 ] is the color black.
# Pixel [ 189 ] [ 114 ] is the color black.
# Pixel [ 190 ] [ 4 ] is the color black.
# Pixel [ 191 ] [ 5 ] is the color black.
# Pixel [ 191 ] [ 6 ] is the color black.
# Pixel [ 191 ] [ 75 ] is the color black.
# Pixel [ 191 ] [ 111 ] is the color black.
# Pixel [ 192 ] [ 8 ] is the color black.
# Pixel [ 192 ] [ 75 ] is the color black.
# Pixel [ 192 ] [ 108 ] is the color black.
# Pixel [ 192 ] [ 109 ] is the color black.
# Pixel [ 193 ] [ 10 ] is the color black.
# Pixel [ 193 ] [ 77 ] is the color black.
# Pixel [ 193 ] [ 106 ] is the color black.
# Pixel [ 193 ] [ 107 ] is the color black.
# Pixel [ 194 ] [ 12 ] is the color black.
# Pixel [ 194 ] [ 78 ] is the color black.
# Pixel [ 194 ] [ 92 ] is the color black.
# Pixel [ 194 ] [ 95 ] is the color black.
# Pixel [ 194 ] [ 96 ] is the color black.
# Pixel [ 194 ] [ 100 ] is the color black.
# Pixel [ 194 ] [ 101 ] is the color black.
# Pixel [ 194 ] [ 102 ] is the color black.
# Pixel [ 194 ] [ 103 ] is the color black.
# Pixel [ 194 ] [ 104 ] is the color black.
# Pixel [ 195 ] [ 13 ] is the color black.
# Pixel [ 195 ] [ 14 ] is the color black.
# Pixel [ 195 ] [ 79 ] is the color black.
# Pixel [ 195 ] [ 92 ] is the color black.
# Pixel [ 195 ] [ 100 ] is the color black.
# Pixel [ 195 ] [ 101 ] is the color black.
# Pixel [ 196 ] [ 14 ] is the color black.
# Pixel [ 196 ] [ 15 ] is the color black.
# Pixel [ 196 ] [ 80 ] is the color black.
# Pixel [ 196 ] [ 94 ] is the color black.
# Pixel [ 196 ] [ 101 ] is the color black.
# Pixel [ 197 ] [ 16 ] is the color black.
# Pixel [ 197 ] [ 17 ] is the color black.
# Pixel [ 197 ] [ 96 ] is the color black.
# Pixel [ 197 ] [ 97 ] is the color black.
# Pixel [ 197 ] [ 102 ] is the color black.
# Pixel [ 198 ] [ 17 ] is the color black.
# Pixel [ 198 ] [ 103 ] is the color black.
# Pixel [ 199 ] [ 18 ] is the color black.
# There are 401 black pixels.

# %% [markdown]
# ### Results
#
# There are 5 white pixels and 401 black pixels.  Visually this makes sense, the large dark areas in her hair must be where most of the black values exist.  Her eyes may look like they are filled with white but our data is telling us different.  Her eyes would contain more than 5 white pixels.  It's good to remember that our monitors can not produce a 100% accurate reproduction of our image data and every human's eyes will interpret color differently.
#
# Let's turn 401 black pixels to red (255,0,0) so we can view where they are in the image and see if at least one of our assumptions is right.

# %%
#Let's turn the black pixels red to show there location.

#Let's save a copy of the image.
imgRed = copy.deepcopy(img)

#Save the RGB value for red.
red = np.array([255,0,0])

#For each row in our grid.
for y in range(0,h):
    #Search each pixel in the row.
    for x in range(0,w):
        #If the RGB values equal black.
        if np.array_equal(imgRed[y,x],black):
            #Turn the black pixel red.
            imgRed[y,x] = red

#Draw the image.  Use matplotlib while using a python notebook. 

plt.figure(figsize=(10,10))
plt.imshow(imgRed)

# %% [markdown]
# ### Our First Image Filter
#
# So far we have searched the pixel array for values that exactly match black or white.  What if you wanted to select all pixels above a certain brightness value?  This seems like a useful tool if you wanted to select those light values in her eyes and face that are not quite 100% white or the dark areas that make up her hair.  The segmenting of an image by it's brightness is called **Thresholding**.
#
# To perform the Threshold filter on our image we set a fixed value as your dividing point between selected pixels and deselected pixels.  If your pixel value(s) are above the brightness threshold they are set to white and if they are below they are set to black.  A Threshold filter returns a binary image.
#
#  Let's first convert our RGB image to greyscale so the brightness is saved in the pixel value.  The following code will take you through the process.

# %%
#Let's turn our image grayscale.

#Let's copy our image 
imgGrey = copy.deepcopy(img)


#For each row in our grid.
for y in range(0,h):
    #Search each pixel in the row
    for x in range(0,w):

        #Converting the color image to greyscale.  Average method.  Divide R,G,B values by 3 and sum them. 
        imgGrey[y,x,0] = img[y,x,0]/3 + img[y,x,1]/3 + img[y,x,2]/3
        imgGrey[y,x,1] = img[y,x,0]/3 + img[y,x,1]/3 + img[y,x,2]/3
        imgGrey[y,x,2] = img[y,x,0]/3 + img[y,x,1]/3 + img[y,x,2]/3
    
    
#Combine the greyscale and the original image so they can be displayed at the same time.  axis=0 for vertical axis=1 for horizontal alignment.
imgTwo = np.concatenate((img, imgGrey), axis=1)

#Draw the image.  Use matplotlib while using a python notebook. 
plt.imshow(imgTwo)

# %%
#Now the OpenCv way to covert to grayscale.

#Convert all the pixels to greyscale values
imgOcvGrey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

#Convert back to RGB to display with plt
imgOcvGrey = cv2.cvtColor(imgOcvGrey, cv2.COLOR_BGR2RGB)

plt.imshow(imgOcvGrey)

# %%
#Threshold filter on our image. 

#Save the height, width, and channel depth.
h = img.shape[0]
w = img.shape[1]
d = img.shape[2]

#Let's copy our image and create a blank image array to store our threshold.
imgGrey = copy.deepcopy(img)
imgThres = np.zeros((img.shape[0],img.shape[1],img.shape[2]), dtype=np.uint8)

#For each row in our grid.
for y in range(0,h):
    #Search each pixel in the row
    for x in range(0,w):
    
        #Converting the color image to greyscale.  Average method.  Divide R,G,B values by 3 and sum them. 
        imgGrey[y,x,0] = img[y,x,0]/3 + img[y,x,1]/3 + img[y,x,2]/3
        imgGrey[y,x,1] = img[y,x,0]/3 + img[y,x,1]/3 + img[y,x,2]/3
        imgGrey[y,x,2] = img[y,x,0]/3 + img[y,x,1]/3 + img[y,x,2]/3

        #Converting a color image to greyscale.  Weighted Method. Weight according to there wavelengths  Formula = ((Red value X 0.299) + (Green value X 0.587) + (Blue value X 0.114)) 
        # imgThres[y,x,0] = img[y,x,0] * 0.299 + img[y,x,1] * 0.587 + img[y,x,2] * 0.114
        # imgThres[y,x,1] = img[y,x,0] * 0.299 + img[y,x,1] * 0.587 + img[y,x,2] * 0.114
        # imgThres[y,x,2] = img[y,x,0] * 0.299 + img[y,x,1] * 0.587 + img[y,x,2] * 0.114

        #Threshold filter on the pixel.

        #If the pixel value is above 100 set it to white.  If it is below 100 set it to black.
        if (imgGrey[y,x,0] > 100):
            imgThres[y,x] = white
        else:
            imgThres[y,x] = black
        

#Combine the greyscale and the threshold image so they can be displayed at the same time.  axis=0 for vertical axis=1 for horizontal alignment.
imgTwo = np.concatenate((imgGrey, imgThres), axis=1)

#Use matplotlib while using a python notebook. Draw the image.
plt.imshow(imgTwo)

# %%
# OpenCv Threshold filter

th, imgOcvThres = cv2.threshold(imgGrey, 100, 255, cv2.THRESH_BINARY);
plt.imshow(imgOcvThres)

# %% [markdown]
# ### Exercises
#
# **(1)** Search for all the white pixels in the provided image.  Save there locations in a 2-D Array.<br><br>
# **(2)** Convert the provided image to greyscale.  Count how many pixels are above the brightness threshold of 100.  Then change the threshold to 150 and count how many pixels are below.  Print both counts. <br>
