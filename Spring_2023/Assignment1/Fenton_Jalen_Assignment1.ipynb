# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

#The array position of 150 is 4 in the 1-D array.
image =  [50,75,100,125,150,175,200,225,250]
#The array position of 150 is [1][1] in the 2-D array.
image2 = [[50,75,100],[125,150,175],[200,225,250]]
print(image)
print(image2) 

img = cv2.imread("Image1.jpg",0)
plt.imshow(img, cmap= 'gray')
print(img.size)
print(img.shape)
print(img.dtype)
print(img)
# Out:
# [50, 75, 100, 125, 150, 175, 200, 225, 250]
# [[50, 75, 100], [125, 150, 175], [200, 225, 250]]
# 37636
# (194, 194)
# uint8
# [[46 46 46 ... 45 46 46]
#  [46 46 46 ... 44 46 46]
#  [46 46 46 ... 45 46 46]
#  ...
#  [45 42 42 ... 37 46 46]
#  [53 46 45 ... 46 40 47]
#  [53 46 45 ... 46 48 55]]
