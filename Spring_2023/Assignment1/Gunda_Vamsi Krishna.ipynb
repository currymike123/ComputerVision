# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#q1a=np.array([50,75,100,125,150,175,200,225,250])
#q1b=np.array([[50,75,100],[125,150,175],[200,225,250]])
q1a=[50,75,100,125,150,175,200,225,250]
q1b=[[50,75,100],[125,150,175],[200,225,250]]
print("1D array is ",q1a)
print("2D array is ",q1b)
# Out:
# 1D array is  [50, 75, 100, 125, 150, 175, 200, 225, 250]
# 2D array is  [[50, 75, 100], [125, 150, 175], [200, 225, 250]]

# %%
#print(np.where(q1a==150))
print(q1a.index(150))
# Out:
# 4

# %%
#print(np.where(q1b==150))
for i in q1b:
    for j in i:
        if(j==150):
            print(q1b.index(i)," ",i.index(150))
# Out:
# 1   1

# %%
img=cv2.imread('naruto.png',1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
