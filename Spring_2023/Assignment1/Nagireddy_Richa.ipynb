# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#Question1
array_1D=[50,75,100,125,150,175,200,225,250]
array_2D=[[50,75,100],[125,150,175],[200,225,250]]
print("printing 1D array: ",array_1D)
print("printing 2D array: ",array_2D)
# Out:
# printing 1D array:  [50, 75, 100, 125, 150, 175, 200, 225, 250]
# printing 2D array:  [[50, 75, 100], [125, 150, 175], [200, 225, 250]]

# %%
#Question2
print(array_1D.index(150))
# Out:
# 4

# %%
#Question3
for i in range(len(array_2D)):
    for j in range(len(array_2D[i])):
        if(array_2D[i][j]==150):
            print(i," ",j)
# Out:
# 1   1

# %%
#Question4
image=cv2.imread('sakura.jpeg',1)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
