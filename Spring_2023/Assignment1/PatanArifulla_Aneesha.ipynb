# %%
import numpy as np
import cv2 as cv2
import matplotlib.pyplot as plt

#Array of values
sequence= 50,75,100,125,150,175,200,225,250

#converting list into array
array = np.array(sequence)

#prininting the values of 1D array
print(sequence)
value1 = np.array(array).reshape(3,3)

#prininting the values of 2D array
print(value1)
# Out:
# (50, 75, 100, 125, 150, 175, 200, 225, 250)
# [[ 50  75 100]
#  [125 150 175]
#  [200 225 250]]

# %%
import numpy as np
import cv2 as cv2
import matplotlib.pyplot as plt

# list of values
array2= 50,75,100,125,150,175,200,225,250
value= 150
#get the position of value in array
position = array2.index(value)

#print/read position
print("The position of value", value, "in the array is", position)
# Out:
# The position of value 150 in the array is 4

# %%
#import libraries
import numpy as np
import cv2 as cv2
import matplotlib.pyplot as plt

# Create a list with the seqence of values
array1 = np.array(array).reshape(3,3)
#print 2D-array
print(array1)

value = 150

#get position in 2D-array
for i in range(3):
  for j in range(3):
    if value == array1[i][j]:
        position = (i, j)
        break
#print position
print("The position of value", value, "in the 2D array is", position)
# Out:
# [[ 50  75 100]
#  [125 150 175]
#  [200 225 250]]
# The position of value 150 in the 2D array is (1, 1)

# %%
#Import Libraries
import numpy as np
import cv2 as cv2
import matplotlib.pyplot as plt

#Saving an image. 0 for grayscale. 1 for color. -1 for color with a alpha channel. 
image = plt.imread('image.jpeg',0)
#display image
plt.imshow(image)
# hiding X-axis and Y-axis of the image
#plt.axis('on')
plt.show()
