# %%
#Import Libraries
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np

#Saving an image. 0 for grayscale. 1 for color. -1 for color with a alpha channel. 
image = plt.imread('rabbit.jpg',0)
#display image
plt.imshow(image)
# hiding X-axis and Y-axis of the image
plt.axis('on')
plt.show()

# %%
# Create a list with the seqence of values
l= 50,75,100,125,150,175,200,225,250

# Convert the list to a 1D array
import numpy as np
array = np.array(l)

# Print the 1D array
print(array)
array1 = np.array(l).reshape(3,3)

# Print the 2D array
print(array1)
# Out:
# [ 50  75 100 125 150 175 200 225 250]
# [[ 50  75 100]
#  [125 150 175]
#  [200 225 250]]

# %%
# Create a list with the seqence of values
array2= 50,75,100,125,150,175,200,225,250
value= 150
#get position of value in array
position = array2.index(value)
#print position
print("The position of value", value, "in the array is", position)
# Out:
# The position of value 150 in the array is 4

# %%
#import libraries
import numpy as np
# Create a list with the seqence of values
array1 = np.array(l).reshape(3,3)
#print 2D-array
print(array1)

value = 150
#get position in 2D-array
for i in range(3):
  for j in range(3):
    if value == array1[i][j]:
        position = (i, j)
        break
#print position
print("The position of value", value, "in the 2D array is", position)
l= 50,75,100,125,150,175,200,225,250
# create an 2D-array using list
# Out:
# [[ 50  75 100]
#  [125 150 175]
#  [200 225 250]]
# The position of value 150 in the 2D array is (1, 1)
