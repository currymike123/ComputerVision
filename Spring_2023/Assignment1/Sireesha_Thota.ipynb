# %%
#import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#declaring the 1D Array variables
array = [50,75,100,125,150,175,200,225,250] 
#declaring the 2D Array variables
array1 = [[50,75,100],[125,150,175],[200,225,250]]
#print the 1D Array
print(array)
#Print the 2D Array
print(array1)
# Out:
# [50, 75, 100, 125, 150, 175, 200, 225, 250]
# [[50, 75, 100], [125, 150, 175], [200, 225, 250]]

# %%
#Declaring the 1D Array
array = [50,75,100,125,150,175,200,225,250]
#Print the array position of 150
print(array.index(150))
# Out:
# 4

# %%
#Declaring the 2D Array
array = np.array([[50,75,100],[125,150,175],[200,225,250]])
#Print the array position of 150
x = np.argwhere(array == 150)
print(x)
# Out:
# [[1 1]]

# %%
#Declaring the image
img = cv2.imread('variable.jpg',1)
#Print the image 
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img)
