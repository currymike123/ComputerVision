# %%
#Taimur Tawil

#import opencv numpy and matplotlib
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
#declare 1d array and assign given values
array1d = [50, 75, 100, 125, 150, 175, 200, 225, 250]
#declare 2d array and assign given values
array2d = [[50, 75, 100],[125, 150, 175],[200, 225, 250]]
#print both arrays
print(array1d)
print(array2d)
# Out:
# [50, 75, 100, 125, 150, 175, 200, 225, 250]
# [[50, 75, 100], [125, 150, 175], [200, 225, 250]]

# %% [markdown]
# In a 1D array the position of 150 is index 4 or array1d[4]

# %% [markdown]
# In a 2D array the position of 150 is array2d[1][1]

# %%
eleetcoderimg = cv.imread('EleetCodersLogo.png', 1)

eleetcoderimg = cv.cvtColor(eleetcoderimg, cv.COLOR_BGR2RGB)
plt.imshow(eleetcoderimg)
