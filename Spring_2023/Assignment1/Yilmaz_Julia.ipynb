# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# Exercise 1

#Declare and store One Dimensional Array with given values
thisOneDimensionalArray = [50,75,100,125,150,175,200,225,250]

#Print stored Two Dimensional Array
print(thisOneDimensionalArray)

#Declare and store One Dimensional Array with given values
thisTwoDimensionalArray = [[50,75,100],[125, 150, 175],[200,225,250]]

#Print stored Two Dimensional Array
print(thisTwoDimensionalArray)
# Out:
# [50, 75, 100, 125, 150, 175, 200, 225, 250]
# [[50, 75, 100], [125, 150, 175], [200, 225, 250]]

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# Exercise 2 

#Prints position of the value 150 in the one Dimensional Array: which is [4]
print("the position of the value 150 in the One Dimensional Array is", thisOneDimensionalArray.index(150))

#Exercise 3

#declare value to search for within Two Dimensional Array
valuePosition = 150

#iterate through Two Dimensional Array to find value 150
for i in range(len(thisTwoDimensionalArray)): 
    for j in range(len(thisTwoDimensionalArray[0])):
        if thisTwoDimensionalArray[i][j]==valuePosition:
            #Print position of value 150 in the two dimensional Array: which is [1][1]
            print("the position of 150 in the Two Dimensional Array is", "row:", i, "column:", j)
            break
# Out:
# the position of the value 150 in the One Dimensional Array is 4
# the position of 150 in the Two Dimensional Array is row: 1 column: 1

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

#saving picture of a mandarin duck

imgDuck = cv2.imread('images/Duck.jpg',0)

#Find number of elements
print(imgDuck.size)

#Show Array shape
print(imgDuck.shape)

#Show element types
print(imgDuck.dtype)

#print data
print(imgDuck)

#print image
plt.imshow(imgDuck, cmap= 'gray')
# Out:
# 50325
# (183, 275)
# uint8
# [[ 66  66  67 ... 134 134 133]
#  [ 58  59  60 ... 131 130 130]
#  [ 49  49  50 ... 122 122 121]
#  ...
#  [181 154 139 ...   8   8   8]
#  [ 64  85 113 ...   9   9   9]
#  [194 233 255 ...   9   9   9]]
