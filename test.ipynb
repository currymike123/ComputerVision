# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('Graphics/face.png')

h = img.shape[0]
w = img.shape[1]

for col in range(0, w):
    for row in range(0,h):
        img[col,row] = img[col,row]

plt.imshow(img, cv2.cvtColor)
